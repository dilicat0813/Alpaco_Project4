# %%
# !pip install dash
# !pip install jupyter-dash
# !pip install dash-bootstrap-components
# Out:
# Collecting dash
#   Using cached dash-2.9.3-py3-none-any.whl (10.2 MB)
# Collecting Flask>=1.0.4
#   Using cached Flask-2.2.3-py3-none-any.whl (101 kB)
# Collecting plotly>=5.0.0
#   Using cached plotly-5.14.1-py2.py3-none-any.whl (15.3 MB)
# Collecting dash-html-components==2.0.0
#   Using cached dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-core-components==2.0.0
#   Using cached dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-table==5.0.0
#   Using cached dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Collecting Werkzeug>=2.2.2
#   Using cached Werkzeug-2.2.3-py3-none-any.whl (233 kB)
# Collecting Jinja2>=3.0
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting itsdangerous>=2.0
#   Using cached itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting click>=8.0
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Collecting tenacity>=6.2.0
#   Using cached tenacity-8.2.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: packaging in c:\users\nike7\appdata\roaming\python\python311\site-packages (from plotly>=5.0.0->dash) (23.1)
# Requirement already satisfied: colorama in c:\users\nike7\appdata\roaming\python\python311\site-packages (from click>=8.0->Flask>=1.0.4->dash) (0.4.6)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.2-cp311-cp311-win_amd64.whl (16 kB)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, tenacity, MarkupSafe, itsdangerous, click, Werkzeug, plotly, Jinja2, Flask, dash
# Successfully installed Flask-2.2.3 Jinja2-3.1.2 MarkupSafe-2.1.2 Werkzeug-2.2.3 click-8.1.3 dash-2.9.3 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 itsdangerous-2.1.2 plotly-5.14.1 tenacity-8.2.2
# [notice] A new release of pip available: 22.3.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting jupyter-dash
#   Using cached jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Requirement already satisfied: dash in c:\users\nike7\appdata\local\programs\python\python311\lib\site-packages (from jupyter-dash) (2.9.3)
# Collecting requests
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ---------------------------------------- 62.8/62.8 kB ? eta 0:00:00
# Requirement already satisfied: flask in c:\users\nike7\appdata\local\programs\python\python311\lib\site-packages (from jupyter-dash) (2.2.3)
# Collecting retrying
#   Using cached retrying-1.3.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: ipython in c:\users\nike7\appdata\roaming\python\python311\site-packages (from jupyter-dash) (8.12.0)
# Requirement already satisfied: ipykernel in c:\users\nike7\appdata\roaming\python\python311\site-packages (from jupyter-dash) (6.22.0)
# Collecting ansi2html
#   Using cached ansi2html-1.8.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: nest-asyncio in c:\users\nike7\appdata\roaming\python\python311\site-packages (from jupyter-dash) (1.5.6)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\nike7\appdata\local\programs\python\python311\lib\site-packages (from dash->jupyter-dash) (5.14.1)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\nike7\appdata\local\programs\python\python311\lib\site-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\nike7\appdata\local\programs\python\python311\lib\site-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\nike7\appdata\local\programs\python\python311\lib\site-packages (from dash->jupyter-dash) (5.0.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\nike7\appdata\local\programs\python\python311\lib\site-packages (from flask->jupyter-dash) (2.2.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\nike7\appdata\local\programs\python\python311\lib\site-packages (from flask->jupyter-dash) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\nike7\appdata\local\programs\python\python311\lib\site-packages (from flask->jupyter-dash) (2.1.2)
# Requirement already satisfied: click>=8.0 in c:\users\nike7\appdata\local\programs\python\python311\lib\site-packages (from flask->jupyter-dash) (8.1.3)
# Requirement already satisfied: comm>=0.1.1 in c:\users\nike7\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter-dash) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\nike7\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter-dash) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\nike7\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter-dash) (8.2.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\nike7\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter-dash) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\nike7\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter-dash) (0.1.6)
# Requirement already satisfied: packaging in c:\users\nike7\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter-dash) (23.1)
# Requirement already satisfied: psutil in c:\users\nike7\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter-dash) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in c:\users\nike7\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter-dash) (25.0.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\nike7\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter-dash) (6.3)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\nike7\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter-dash) (5.9.0)
# Requirement already satisfied: backcall in c:\users\nike7\appdata\roaming\python\python311\site-packages (from ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: decorator in c:\users\nike7\appdata\roaming\python\python311\site-packages (from ipython->jupyter-dash) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\nike7\appdata\roaming\python\python311\site-packages (from ipython->jupyter-dash) (0.18.2)
# Requirement already satisfied: pickleshare in c:\users\nike7\appdata\roaming\python\python311\site-packages (from ipython->jupyter-dash) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\nike7\appdata\roaming\python\python311\site-packages (from ipython->jupyter-dash) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\nike7\appdata\roaming\python\python311\site-packages (from ipython->jupyter-dash) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\nike7\appdata\roaming\python\python311\site-packages (from ipython->jupyter-dash) (0.6.2)
# Requirement already satisfied: colorama in c:\users\nike7\appdata\roaming\python\python311\site-packages (from ipython->jupyter-dash) (0.4.6)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.1.0-cp311-cp311-win_amd64.whl (96 kB)
#      ---------------------------------------- 96.7/96.7 kB ? eta 0:00:00
# Collecting idna<4,>=2.5
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.15-py2.py3-none-any.whl (140 kB)
#      ---------------------------------------- 140.9/140.9 kB ? eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
#      ---------------------------------------- 155.3/155.3 kB ? eta 0:00:00
# Requirement already satisfied: six>=1.7.0 in c:\users\nike7\appdata\roaming\python\python311\site-packages (from retrying->jupyter-dash) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\nike7\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython->jupyter-dash) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nike7\appdata\local\programs\python\python311\lib\site-packages (from Jinja2>=3.0->flask->jupyter-dash) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nike7\appdata\roaming\python\python311\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\nike7\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter-dash) (3.2.0)
# Requirement already satisfied: pywin32>=300 in c:\users\nike7\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter-dash) (306)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\nike7\appdata\local\programs\python\python311\lib\site-packages (from plotly>=5.0.0->dash->jupyter-dash) (8.2.2)
# Requirement already satisfied: wcwidth in c:\users\nike7\appdata\roaming\python\python311\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->jupyter-dash) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in c:\users\nike7\appdata\roaming\python\python311\site-packages (from stack-data->ipython->jupyter-dash) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\nike7\appdata\roaming\python\python311\site-packages (from stack-data->ipython->jupyter-dash) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\nike7\appdata\roaming\python\python311\site-packages (from stack-data->ipython->jupyter-dash) (0.2.2)
# Installing collected packages: urllib3, retrying, idna, charset-normalizer, certifi, ansi2html, requests, jupyter-dash
# Successfully installed ansi2html-1.8.0 certifi-2022.12.7 charset-normalizer-3.1.0 idna-3.4 jupyter-dash-0.4.2 requests-2.28.2 retrying-1.3.4 urllib3-1.26.15
# [notice] A new release of pip available: 22.3.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting dash-bootstrap-components
#   Using cached dash_bootstrap_components-1.4.1-py3-none-any.whl (220 kB)
# Requirement already satisfied: dash>=2.0.0 in c:\users\nike7\appdata\local\programs\python\python311\lib\site-packages (from dash-bootstrap-components) (2.9.3)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\nike7\appdata\local\programs\python\python311\lib\site-packages (from dash>=2.0.0->dash-bootstrap-components) (2.2.3)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\nike7\appdata\local\programs\python\python311\lib\site-packages (from dash>=2.0.0->dash-bootstrap-components) (5.14.1)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\nike7\appdata\local\programs\python\python311\lib\site-packages (from dash>=2.0.0->dash-bootstrap-components) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\nike7\appdata\local\programs\python\python311\lib\site-packages (from dash>=2.0.0->dash-bootstrap-components) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\nike7\appdata\local\programs\python\python311\lib\site-packages (from dash>=2.0.0->dash-bootstrap-components) (5.0.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\nike7\appdata\local\programs\python\python311\lib\site-packages (from Flask>=1.0.4->dash>=2.0.0->dash-bootstrap-components) (2.2.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\nike7\appdata\local\programs\python\python311\lib\site-packages (from Flask>=1.0.4->dash>=2.0.0->dash-bootstrap-components) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\nike7\appdata\local\programs\python\python311\lib\site-packages (from Flask>=1.0.4->dash>=2.0.0->dash-bootstrap-components) (2.1.2)
# Requirement already satisfied: click>=8.0 in c:\users\nike7\appdata\local\programs\python\python311\lib\site-packages (from Flask>=1.0.4->dash>=2.0.0->dash-bootstrap-components) (8.1.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\nike7\appdata\local\programs\python\python311\lib\site-packages (from plotly>=5.0.0->dash>=2.0.0->dash-bootstrap-components) (8.2.2)
# Requirement already satisfied: packaging in c:\users\nike7\appdata\roaming\python\python311\site-packages (from plotly>=5.0.0->dash>=2.0.0->dash-bootstrap-components) (23.1)
# Requirement already satisfied: colorama in c:\users\nike7\appdata\roaming\python\python311\site-packages (from click>=8.0->Flask>=1.0.4->dash>=2.0.0->dash-bootstrap-components) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nike7\appdata\local\programs\python\python311\lib\site-packages (from Jinja2>=3.0->Flask>=1.0.4->dash>=2.0.0->dash-bootstrap-components) (2.1.2)
# Installing collected packages: dash-bootstrap-components
# Successfully installed dash-bootstrap-components-1.4.1
# [notice] A new release of pip available: 22.3.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import plotly.express as px
from jupyter_dash import JupyterDash
from dash import Dash, dcc, html, Input, Output
import dash_bootstrap_components as dbc
import plotly.graph_objs as go

from pre1_booking_data import year_earn, buyer

# import year_earn, buyer form csv file
# year_earn = pd.read_csv('data/year_earn.csv')
# buyer = pd.read_csv('data/buyer.csv')

#스캐터 5개 그래프 
scatter5 = pd.read_csv('data/scatter5.csv')
scatter5_names = ['충전실온도', '실링온도', '쿠킹온도', '쿠킹스팀압력', '실링압력']
# fig1 = px.scatter(scatter5, x = scatter5['생산일자'], y = scatter5['쿠킹스팀압력'], color = scatter5['오류발생여부'])
# fig2 = px.scatter(scatter5, x = scatter5['생산일자'], y = scatter5['충전실온도'], color = scatter5['오류발생여부'])
# fig3 = px.scatter(scatter5, x = scatter5['생산일자'], y = scatter5['실링온도'], color = scatter5['오류발생여부'])
# fig4 = px.scatter(scatter5, x = scatter5['생산일자'], y = scatter5['쿠킹온도'], color = scatter5['오류발생여부'])
# fig5 = px.scatter(scatter5, x = scatter5['생산일자'], y = scatter5['실링압력'], color = scatter5['오류발생여부'])

#파이그래프1(110)
pie1 = pd.read_csv('data/pie1.csv')
pie1 = pie1.drop('name_y', axis=1)
pie1.rename(columns={'name_x': 'name'}, inplace=True) #간단한 드롭
# fig_pie1 = go.Figure(data=[go.Pie(labels=pie1['name'], values=pie1['Error_class']/2, textinfo='label+percent',
#                              insidetextorientation='radial'
#                             )])
# fig_pie1.show()

#파이그래프2(1074)
merge3 = pd.read_csv('data/merge3.csv')
pie2 = px.pie(merge3, values='Error_class', names='Error_class')

#연단위 오류 발생률
Error_per = pd.read_csv('data/new_Error_per.csv')
Error_per['오류발생률']=Error_per['오류발생률'].round(2)
# fig = px.line(Error_per, x="year", y="per", text="per")
# fig.update_traces(textposition="bottom right")

#바이올린 차트_생산시간
violin_cooking = pd.read_csv('data/violin_cooking.csv')
vio1 = px.violin(violin_cooking, box=True, y='생산시간')

#바이올린 차트_오류발생시간
violin_error = pd.read_csv('data/violin_error.csv')
vio2 = px.violin(violin_error, box=True, y='오류조치시간_보정')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2 import plotly.express as px
#       3 from jupyter_dash import JupyterDash
#
# ModuleNotFoundError: No module named 'pandas'

# %%
def Header2(name, app):
    title = html.H2(name, style={"margin-top": 5})
    return dbc.Row([dbc.Col(title, md=9)])

def Header1(name, app):
    title = html.H1(name, style={"margin-top": 5})
    return dbc.Row([dbc.Col(title, md=9)])

#데이터 프레임 생성
df = pd.DataFrame({
    'year':[2016, 2017, 2018, 2019, 2020, 2021, 2022],
    'market': [227000000000, 274000000000, 320000000000, 350000000000, 400000000000, 450000000000, 500000000000]
})

년_간편식_HMR__구입_변화_예상_1 = pd.DataFrame({'names': ['현 수준 유지', '약간 증가', '약간 감소', '매우 감소'],
                   'values': [74.9, 22.5, 2.4, 0.2]})

#id=update_graph2, fig3
fig3 = px.pie(년_간편식_HMR__구입_변화_예상_1, values=[74.9, 22.5, 2.4, 0.2], names=['현 수준 유지', '약간 증가', '약간 감소', ' 매우 감소'])
fig3.update_traces(textposition='inside', textinfo='percent+label')
fig3.update_layout(
    annotations=[dict(x=0.5, y=1.2, showarrow=False, text='향후 1년 HMR 구입 변화 예상', font=dict(size=20))],
    margin=dict(t=100)
)

# Card components

# Basement Cards
cards = [
    dbc.Card(
        [
            html.H2(f"{5/45*100}%", className="card-title"),
            html.P("HMR Market Increasing", className="card-text"),
        ],
        body=True,
        color="dark",
        inverse=True,
    ),
    dbc.Card(
        [
            html.H2(f"계산식 미정", className="card-title"),
            html.P("Decline in Company Sales", className="card-text"),
        ],
        body=True,
        color="primary",
        inverse=True,
    ),
]

# Analyze Cards
cards2 = [
    dbc.Card(
        [
            html.H2(f"Analyze1", className="card-title"),
            html.P("Error1", className="card-text"),
        ],
        body=True,
        color="dark",
        inverse=True,
    ),
    dbc.Card(
        [
            html.H2(f"Analyze2", className="card-title"),
            html.P("Error2", className="card-text"),
        ],
        body=True,
        color="primary",
        inverse=True,
    ),
]

# Predict Cards(추후 추가)


cards3 = [
    dbc.Card(
        [
            html.H2(f"Predict1", className="card-title"),
            html.P("Modeling1", className="card-text"),
        ],
        body=True,
        color="dark",
        inverse=True,
    ),
    dbc.Card(
        [
            html.H2(f"Predict2", className="card-title"),
            html.P("Modeling2", className="card-text"),
        ],
        body=True,
        color="primary",
        inverse=True,
    ),
]

# Graph components
# Basement_Graphs
graphs1 = [[dcc.Graph(id="update_graph"), #1행 1열
            dcc.RangeSlider(df['year'].min(),
                            df['year'].max(),
                            value=[df['year'].min(), df['year'].max()], #수정사항, 슬라이더 초기값(처음값과 끝값)
                            marks={str(year): str(year) for year in df['year'].unique()}, #수정사항 RangeSlider, Slider 모두에 적용
                            id='slider1')]
            , [dcc.Graph(id="update_graph2", figure=fig3)]] #1행 2열

graphs2 = [[dcc.Graph(id='booking-with-graph'), #2행 1열
            dcc.RangeSlider(id='year-slider',
                            min=year_earn['year'].min(),
                            max=year_earn['year'].max(),
                            value=[year_earn['year'].min(), year_earn['year'].max()],
                            marks={str(year): str(year) for year in year_earn['year'].unique()})],
           [dcc.Graph(id='yearly-transaction-graph'), #2행 2열
            dcc.RangeSlider(id='year-slider2',
                            min= buyer['year'].min(),
                            max= buyer['year'].max(),
                            step=None,
                            value=[buyer['year'].min(), buyer['year'].max()],
                            marks={str(year): str(year) for year in buyer['year'].unique()})
            ]]
        
# Analyze Graph

graphs3 = [[dcc.Graph(id="scatter-5"),
            dcc.Dropdown(id='yvar_name',
                     options=scatter5_names,
                     value=scatter5_names[0],
                     placeholder='Select X-axis column')],  #Dropdown 변경은 자율
           ]

graphs4 = [[dcc.Graph(id='Error_per'), #연도별 오류 파이그래프
            dcc.RangeSlider(id='year-per',
                            min=Error_per['연도'].min(),
                            max=Error_per['연도'].max(),
                            value=[Error_per['연도'].min(), Error_per['연도'].max()],
                            marks={str(year): str(year) for year in Error_per['연도'].unique()})
            ]]
# graphs4 = [[dcc.Graph(id=""),
#             dcc.Dropdown()],
#            [dcc.Graph(id=""),
#             dcc.Dropdown()]]


# Predict Graph(추후 추가)

# graphs5 = [[dcc.Graph(id=""),
#             dcc.Dropdown()],  #Dropdown 변경은 자율
#            [dcc.Graph(id=""),
#             dcc.Dropdown()]]

# graphs6 = [[dcc.Graph(id=""),
#             dcc.Dropdown()],
#            [dcc.Graph(id=""),
#             dcc.Dropdown()]]



app = JupyterDash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

app.layout = dbc.Container(
    [
        Header1("불량예측 모델을 통한 수익성 개선", app),
        html.Hr(),
        Header2("Basement", app),
        html.Br(),
        dbc.Row([dbc.Col(card) for card in cards]),
        html.Br(),
        dbc.Row([dbc.Col(graph) for graph in graphs1]),
        html.Br(),
        dbc.Row([dbc.Col(graph) for graph in graphs2]),
        html.Br(),
        html.Hr(),
        Header2("Analyze", app),
        html.Br(),
        dbc.Row([dbc.Col(card) for card in cards2]),
        html.Br(),
        dbc.Row([dbc.Col(graph) for graph in graphs3]), #그래프3 
        html.Br(),
        dbc.Row([dbc.Col(graph) for graph in graphs4]), #그래프4
        html.Br(),
        html.Hr(),
        Header2("Predict", app),
        html.Br(),
        dbc.Row([dbc.Col(card) for card in cards3]),
        # html.Br(),
        # dbc.Row([dbc.Col(graph) for graph in graphs3]), #그래프3 
        # html.Br(),
        # dbc.Row([dbc.Col(graph) for graph in graphs4]), #그래프4  
    ],
    fluid=False,
)

#Basement Graph Callback list
    #그래프 1행 1열 콜백
@app.callback(
    Output(component_id='update_graph', component_property='figure'), 
    Input(component_id='slider1', component_property='value')
)
def update_graph(year):
    filtered_df = df[(df['year'] >= year[0]) & (df['year'] <= year[1])] #수정사항, 슬라이더 값지정하는 임시 df생성
    fig1 = px.bar(filtered_df, x=filtered_df['year'], y=filtered_df['market'])
    fig1.update_layout(title_text="HMR Market Changes",
                      title_font_size=30)
    return(fig1)


    #그래프 2행 1열 콜백
@app.callback(
    Output(component_id='booking-with-graph', component_property='figure'), 
    Input(component_id='year-slider', component_property='value')
)
def update_graph2(year):
    filtered_df2 = year_earn[(year_earn['year'] >= year[0]) & (year_earn['year'] <= year[1])]
    fig2 = px.bar(filtered_df2, x='year', y='수주금액')
    fig2.update_layout(title_text="연도별 수주금액추이",title_font_size=30)
    return(fig2)           

    #그래프 2행 2열 콜백
@app.callback(
    Output(component_id='yearly-transaction-graph', component_property='figure'),
    Input(component_id='year-slider2', component_property='value')
)
def update_figure(selected_years):
    filtered_df3 = buyer[(buyer['year'] >= selected_years[0]) & (buyer['year'] <= selected_years[1])]
    fig4 = go.Figure(data=[go.Bar(x=filtered_df3['year'], y=filtered_df3['거래처코드'])],
                     layout=go.Layout(title=go.layout.Title(text="연도별 거래건수 변동추이", x=0.5),
                                      xaxis=dict(title='연도'),
                                      yaxis=dict(title='거래건수'),
                                      barmode='group')
                    )
    return fig4
     
#Analyze Graph Callback list
    #그래프 1행 1열 콜백
@app.callback(
    Output(component_id='scatter-5', component_property='figure'),
     Input(component_id='yvar_name', component_property='value')
)
def update_graph(yvar):
    fig = px.scatter(scatter5, x=scatter5['생산일자'], y=yvar, color=scatter5['오류발생여부'])
    fig.update_layout(title_text="오류발생요인("+yvar+')에 따른 오류제품 분포 ',
                      title_font_size=30)
    return(fig)  
    #연도별 오류 발생률
@app.callback(
    Output(component_id='Error_per', component_property='figure'), 
    Input(component_id='year-per', component_property='value')
)
def update_figure(year):
    filtered_year_per = Error_per[(Error_per['연도'] >= year[0]) & (Error_per['연도'] <= year[1])]
    fig_year_per = px.line(filtered_year_per, x='연도', y='오류발생률')
    fig_year_per.update_layout(title_text="연도별 오류발생률",title_font_size=30)
    return(fig_year_per)              
           
# year per
#            graphs4 = [[dcc.Graph(id='Error_per'), #연도별 오류 파이그래프
#             dcc.RangeSlider(id='year-per',
#                             min=year_earn['year'].min(),
#                             max=year_earn['year'].max(),
#                             value=[Error_per['year'].min(), Error_per['year'].max()],
#                             marks={str(year): str(year) for year in Error_per['year'].unique()})],
           
    #그래프 1행 2열 콜백

    #그래프 2행 1열 콜백

    #그래프 2행 2열 콜백

    #그래프 3행 1열 콜백

#Predict Graph Callback list
    #그래프 1행 1열 콜백

    #그래프 1행 2열 콜백

    #그래프 2행 1열 콜백

    #그래프 2행 2열 콜백

    #그래프 3행 1열 콜백

if __name__ == '__main__':
    app.run_server(debug=True, mode='inline', host='127.0.0.7')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 10
#       7     return dbc.Row([dbc.Col(title, md=9)])
#       9 #데이터 프레임 생성
# ---> 10 df = pd.DataFrame({
#      11     'year':[2016, 2017, 2018, 2019, 2020, 2021, 2022],
#      12     'market': [227000000000, 274000000000, 320000000000, 350000000000, 400000000000, 450000000000, 500000000000]
#      13 })
#      15 년_간편식_HMR__구입_변화_예상_1 = pd.DataFrame({'names': ['현 수준 유지', '약간 증가', '약간 감소', '매우 감소'],
#      16                    'values': [74.9, 22.5, 2.4, 0.2]})
#      18 #id=update_graph2, fig3
#
# NameError: name 'pd' is not defined

# %% [markdown]
# from dash import Dash, html, dcc, Input, Output
# import plotly.express as px
# import pandas as pd
# from jupyter_dash import JupyterDash
#
# import pandas as pd
# import plotly.express as px
# from jupyter_dash import JupyterDash
# import dash_html_components as html
# import dash_core_components as dcc
#
# 년_간편식_HMR__구입_변화_예상_1 = pd.DataFrame({'names': ['현 수준 유지', '약간 증가', '약간 감소', '매우 감소'],
#                    'values': [74.9, 22.5, 2.4, 0.2]})
# import plotly.express as px
#
# fig = px.pie(년_간편식_HMR__구입_변화_예상_1, values=[74.9, 22.5, 2.4, 0.2], names=['현 수준 유지', '약간 증가', '약간 감소', ' 매우 감소'])
# fig.update_traces(textposition='inside', textinfo='percent+label')
# fig.update_layout(
#     annotations=[dict(x=0.5, y=1.2, showarrow=False, text='향후 1년 HMR 구입 변화 예상', font=dict(size=20))],
#     margin=dict(t=100)
# )
# app = JupyterDash(__name__)
#
# app.layout = html.Div([
#     dcc.Graph(id='graph', figure=fig)
# ])
#
# app.run_server(mode='inline')
#
#
#
# ,
#         dcc.RangeSlider(id='year-slider',
#                         min=year_earn['year'].min(),
#                         max=year_earn['year'].max(),
#                         value=[year_earn['year'].min(), year_earn['year'].max()],
#                         marks={str(year): str(year) for year in year_earn['year'].unique()})
