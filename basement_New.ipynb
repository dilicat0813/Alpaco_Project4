# %%
## Install modules Area

# !pip install dash
# !pip install jupyter-dash
# !pip install dash-bootstrap-components
# !pip install statsmodels
# !pip install catboost

## Import Modules Area
import pandas as pd
import dash
import plotly.express as px
from jupyter_dash import JupyterDash
from dash import Dash, dcc, html, Input, Output
import dash_bootstrap_components as dbc
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import numpy as np
from catboost import CatBoostClassifier
import base64

# %%
# DataFrame 정의 Area

# import year_earn, buyer form csv file
year_earn = pd.read_csv('data/year_earn.csv')
buyer = pd.read_csv('data/buyer.csv')

#스캐터 5개 그래프 
scatter5 = pd.read_csv('data/scatter5.csv')
scatter5_names = ['충전실온도', '실링온도', '쿠킹온도', '쿠킹스팀압력', '실링압력'] #dropdown 목록 지정을 위한 정의
# fig1 = px.scatter(scatter5, x = scatter5['생산일자'], y = scatter5['쿠킹스팀압력'], color = scatter5['오류발생여부'])
# fig2 = px.scatter(scatter5, x = scatter5['생산일자'], y = scatter5['충전실온도'], color = scatter5['오류발생여부'])
# fig3 = px.scatter(scatter5, x = scatter5['생산일자'], y = scatter5['실링온도'], color = scatter5['오류발생여부'])
# fig4 = px.scatter(scatter5, x = scatter5['생산일자'], y = scatter5['쿠킹온도'], color = scatter5['오류발생여부'])
# fig5 = px.scatter(scatter5, x = scatter5['생산일자'], y = scatter5['실링압력'], color = scatter5['오류발생여부'])

#파이그래프1(110)
pie1 = pd.read_csv('data/pie1.csv')
pie1 = pie1.drop('name_y', axis=1)
pie1.rename(columns={'name_x': 'name'}, inplace=True) #간단한 드롭
pie1= pie1.groupby('name')['Error_class'].count()
# fig_pie1 = px.pie(pie1, values='Error_class', names=pie1.index)

#파이그래프2(1074)
pie2 = pd.read_csv('data/errored_pie.csv')
pie2 = pie2.groupby('name')['Error_class'].count()
#fig_pie2 = px.pie(pie2, values='Error_class', names=pie2.index)

#연단위 오류 발생률
Error_per = pd.read_csv('data/Error_per.csv')
Error_per['per'] = Error_per['per'].round(2)
# fig = px.line(Error_per, x="year", y="per", text="per")
# fig.update_traces(textposition="bottom right")

#바이올린 차트_생산시간
violin_cooking = pd.read_csv('data/violin_cooking.csv')
#vio1 = px.violin(violin_cooking, box=True, y='생산시간')

#바이올린 차트_오류발생시간
violin_error = pd.read_csv('data/violin_error.csv')
#vio2 = px.violin(violin_error, box=True, y='오류조치시간_보정')

#HMR 시장 확대 
hmrexpand = pd.read_csv('data/hmrexpand.csv')

#간편식 HMR 구입 변화 예상
hmrchange = pd.read_csv('data/hmr_change_predict.csv')
fig3 = px.pie(hmrchange, values='values', names='names')
fig3.update_traces(textposition='inside', textinfo='percent+label')
fig3.update_layout(
    annotations=[dict(x=0.5, y=1.2, showarrow=False, text='향후 1년 HMR 구입 변화 예상', font=dict(size=20))],
    margin=dict(t=100)
)

#라인2개 그래프 & 상관관계 그래프 데이터 프레임
cooking_error_quarter = pd.read_csv('data/cooking_error_quarter.csv')

#상관관계
# fig = px.scatter(cooking_error_quarter, x=cooking_error_quarter["생산수"], y=cooking_error_quarter["오류발생여부"], trendline="ols")
# fig.update_layout(title_text="분기별 생산품목과 오류발생")

#라인2개 그래프
# fig = make_subplots(specs=[[{"secondary_y": True}]])
# fig.add_trace(
#     go.Scatter( x = cooking_error_quarter["quarter"], y = cooking_error_quarter["생산수"],
#     mode = 'lines', name = '분기별 간편식 생산품목 수'),
#     secondary_y=False,)
# fig.add_trace(
#     go.Scatter( x = cooking_error_quarter["quarter"], y = cooking_error_quarter["오류발생여부"],
#     mode = 'lines', name = '분기별 오류발생 현황'),
#     secondary_y=True,)
# # Add figure title
# fig.update_layout(
#     title_text="분기별 생산품목과 오류발생")
# fig.update_xaxes(title_text="분기")
# fig.update_yaxes(title_text="<b>생산품목</b>", secondary_y=False)
# fig.update_yaxes(title_text="<b>오류발생</b>", secondary_y=True)

#f1-score table
f1_score_df = pd.read_csv('data/f1_score.csv')

# %%
#CatBoost 학습 모델 load Area
model = CatBoostClassifier()
model.load_model('model/catboost_model_multi.dump') 

#모델 평가 부분 불러오기
from cb_model import train_score, test_score, y_pred, report, importance, X
# Out:
# Learning rate set to 0.09201
# 0:	learn: 1.1356003	total: 143ms	remaining: 2m 22s
# 1:	learn: 0.9600317	total: 146ms	remaining: 1m 12s
# 2:	learn: 0.8287757	total: 148ms	remaining: 49.3s
# 3:	learn: 0.7234999	total: 151ms	remaining: 37.6s
# 4:	learn: 0.6375743	total: 154ms	remaining: 30.6s
# 5:	learn: 0.5662998	total: 157ms	remaining: 25.9s
# 6:	learn: 0.5060537	total: 159ms	remaining: 22.6s
# 7:	learn: 0.4552699	total: 162ms	remaining: 20.1s
# 8:	learn: 0.4106319	total: 165ms	remaining: 18.2s
# 9:	learn: 0.3720505	total: 168ms	remaining: 16.6s
# 10:	learn: 0.3380672	total: 171ms	remaining: 15.3s
# 11:	learn: 0.3081440	total: 173ms	remaining: 14.3s
# 12:	learn: 0.2817334	total: 176ms	remaining: 13.4s
# 13:	learn: 0.2587311	total: 179ms	remaining: 12.6s
# 14:	learn: 0.2379639	total: 181ms	remaining: 11.9s
# 15:	learn: 0.2193259	total: 184ms	remaining: 11.3s
# 16:	learn: 0.2027010	total: 187ms	remaining: 10.8s
# 17:	learn: 0.1879276	total: 189ms	remaining: 10.3s
# 18:	learn: 0.1745576	total: 192ms	remaining: 9.92s
# 19:	learn: 0.1625297	total: 195ms	remaining: 9.54s
# 20:	learn: 0.1514153	total: 197ms	remaining: 9.2s
# 21:	learn: 0.1415623	total: 201ms	remaining: 8.91s
# 22:	learn: 0.1328944	total: 203ms	remaining: 8.64s
# 23:	learn: 0.1249096	total: 206ms	remaining: 8.38s
# 24:	learn: 0.1178895	total: 209ms	remaining: 8.14s
# 25:	learn: 0.1114415	total: 211ms	remaining: 7.91s
# 26:	learn: 0.1055594	total: 214ms	remaining: 7.7s
# 27:	learn: 0.1002748	total: 217ms	remaining: 7.52s
# 28:	learn: 0.0951256	total: 219ms	remaining: 7.35s
# 29:	learn: 0.0908696	total: 222ms	remaining: 7.18s
# 30:	learn: 0.0866499	total: 225ms	remaining: 7.03s
# 31:	learn: 0.0827987	total: 227ms	remaining: 6.88s
# 32:	learn: 0.0794650	total: 230ms	remaining: 6.74s
# 33:	learn: 0.0763168	total: 233ms	remaining: 6.62s
# 34:	learn: 0.0735562	total: 236ms	remaining: 6.5s
# 35:	learn: 0.0712280	total: 238ms	remaining: 6.37s
# 36:	learn: 0.0688927	total: 240ms	remaining: 6.26s
# 37:	learn: 0.0667844	total: 243ms	remaining: 6.16s
# 38:	learn: 0.0649436	total: 246ms	remaining: 6.05s
# 39:	learn: 0.0632373	total: 249ms	remaining: 5.97s
# 40:	learn: 0.0615784	total: 252ms	remaining: 5.89s
# 41:	learn: 0.0599598	total: 254ms	remaining: 5.8s
# 42:	learn: 0.0586025	total: 257ms	remaining: 5.71s
# 43:	learn: 0.0573437	total: 259ms	remaining: 5.63s
# 44:	learn: 0.0562535	total: 262ms	remaining: 5.56s
# 45:	learn: 0.0552370	total: 265ms	remaining: 5.49s
# 46:	learn: 0.0544585	total: 267ms	remaining: 5.42s
# 47:	learn: 0.0535833	total: 270ms	remaining: 5.35s
# 48:	learn: 0.0528127	total: 273ms	remaining: 5.29s
# 49:	learn: 0.0521077	total: 275ms	remaining: 5.23s
# 50:	learn: 0.0514764	total: 278ms	remaining: 5.18s
# 51:	learn: 0.0508774	total: 281ms	remaining: 5.12s
# 52:	learn: 0.0502897	total: 284ms	remaining: 5.07s
# 53:	learn: 0.0497759	total: 286ms	remaining: 5.01s
# 54:	learn: 0.0492481	total: 289ms	remaining: 4.96s
# 55:	learn: 0.0487763	total: 292ms	remaining: 4.91s
# 56:	learn: 0.0484056	total: 294ms	remaining: 4.87s
# 57:	learn: 0.0480680	total: 297ms	remaining: 4.82s
# 58:	learn: 0.0477591	total: 300ms	remaining: 4.78s
# 59:	learn: 0.0475090	total: 303ms	remaining: 4.74s
# 60:	learn: 0.0471477	total: 305ms	remaining: 4.7s
# 61:	learn: 0.0468152	total: 308ms	remaining: 4.66s
# 62:	learn: 0.0464946	total: 310ms	remaining: 4.61s
# 63:	learn: 0.0462174	total: 313ms	remaining: 4.58s
# 64:	learn: 0.0460197	total: 316ms	remaining: 4.54s
# 65:	learn: 0.0457768	total: 318ms	remaining: 4.5s
# 66:	learn: 0.0456397	total: 321ms	remaining: 4.47s
# 67:	learn: 0.0454486	total: 323ms	remaining: 4.43s
# 68:	learn: 0.0452852	total: 326ms	remaining: 4.4s
# 69:	learn: 0.0450852	total: 329ms	remaining: 4.36s
# 70:	learn: 0.0449631	total: 331ms	remaining: 4.33s
# 71:	learn: 0.0447801	total: 334ms	remaining: 4.31s
# 72:	learn: 0.0446665	total: 337ms	remaining: 4.28s
# 73:	learn: 0.0445314	total: 340ms	remaining: 4.25s
# 74:	learn: 0.0443973	total: 342ms	remaining: 4.22s
# 75:	learn: 0.0443071	total: 345ms	remaining: 4.19s
# 76:	learn: 0.0442265	total: 348ms	remaining: 4.17s
# 77:	learn: 0.0440961	total: 350ms	remaining: 4.14s
# 78:	learn: 0.0439725	total: 353ms	remaining: 4.11s
# 79:	learn: 0.0438597	total: 355ms	remaining: 4.08s
# 80:	learn: 0.0437856	total: 358ms	remaining: 4.06s
# 81:	learn: 0.0436637	total: 360ms	remaining: 4.03s
# 82:	learn: 0.0435881	total: 363ms	remaining: 4.01s
# 83:	learn: 0.0434684	total: 366ms	remaining: 3.99s
# 84:	learn: 0.0433383	total: 368ms	remaining: 3.96s
# 85:	learn: 0.0432513	total: 371ms	remaining: 3.94s
# 86:	learn: 0.0431596	total: 374ms	remaining: 3.92s
# 87:	learn: 0.0430818	total: 376ms	remaining: 3.9s
# 88:	learn: 0.0429576	total: 378ms	remaining: 3.87s
# 89:	learn: 0.0428943	total: 381ms	remaining: 3.85s
# 90:	learn: 0.0428020	total: 384ms	remaining: 3.83s
# 91:	learn: 0.0427387	total: 386ms	remaining: 3.81s
# 92:	learn: 0.0425880	total: 389ms	remaining: 3.79s
# 93:	learn: 0.0425017	total: 391ms	remaining: 3.77s
# 94:	learn: 0.0423729	total: 394ms	remaining: 3.75s
# 95:	learn: 0.0422480	total: 397ms	remaining: 3.73s
# 96:	learn: 0.0421711	total: 399ms	remaining: 3.72s
# 97:	learn: 0.0421036	total: 402ms	remaining: 3.7s
# 98:	learn: 0.0420536	total: 404ms	remaining: 3.68s
# 99:	learn: 0.0419884	total: 407ms	remaining: 3.66s
# 100:	learn: 0.0419283	total: 409ms	remaining: 3.64s
# 101:	learn: 0.0418377	total: 412ms	remaining: 3.63s
# 102:	learn: 0.0417335	total: 415ms	remaining: 3.61s
# 103:	learn: 0.0416891	total: 417ms	remaining: 3.6s
# 104:	learn: 0.0415952	total: 420ms	remaining: 3.58s
# 105:	learn: 0.0415460	total: 423ms	remaining: 3.56s
# 106:	learn: 0.0414936	total: 425ms	remaining: 3.55s
# 107:	learn: 0.0413895	total: 428ms	remaining: 3.53s
# 108:	learn: 0.0412805	total: 431ms	remaining: 3.52s
# 109:	learn: 0.0412375	total: 434ms	remaining: 3.51s
# 110:	learn: 0.0411841	total: 436ms	remaining: 3.49s
# 111:	learn: 0.0411395	total: 439ms	remaining: 3.48s
# 112:	learn: 0.0410552	total: 441ms	remaining: 3.46s
# 113:	learn: 0.0409850	total: 444ms	remaining: 3.45s
# 114:	learn: 0.0409337	total: 447ms	remaining: 3.44s
# 115:	learn: 0.0408546	total: 449ms	remaining: 3.42s
# 116:	learn: 0.0407994	total: 452ms	remaining: 3.41s
# 117:	learn: 0.0407023	total: 454ms	remaining: 3.4s
# 118:	learn: 0.0406492	total: 457ms	remaining: 3.38s
# 119:	learn: 0.0405949	total: 459ms	remaining: 3.37s
# 120:	learn: 0.0405611	total: 462ms	remaining: 3.36s
# 121:	learn: 0.0405217	total: 464ms	remaining: 3.34s
# 122:	learn: 0.0404763	total: 467ms	remaining: 3.33s
# 123:	learn: 0.0404090	total: 470ms	remaining: 3.32s
# 124:	learn: 0.0403785	total: 472ms	remaining: 3.3s
# 125:	learn: 0.0403009	total: 475ms	remaining: 3.29s
# 126:	learn: 0.0402682	total: 477ms	remaining: 3.28s
# 127:	learn: 0.0402083	total: 480ms	remaining: 3.27s
# 128:	learn: 0.0401293	total: 482ms	remaining: 3.26s
# 129:	learn: 0.0400887	total: 485ms	remaining: 3.24s
# 130:	learn: 0.0400166	total: 487ms	remaining: 3.23s
# 131:	learn: 0.0399584	total: 490ms	remaining: 3.22s
# 132:	learn: 0.0399012	total: 492ms	remaining: 3.21s
# 133:	learn: 0.0398317	total: 495ms	remaining: 3.2s
# 134:	learn: 0.0397648	total: 498ms	remaining: 3.19s
# 135:	learn: 0.0397017	total: 500ms	remaining: 3.18s
# 136:	learn: 0.0396690	total: 503ms	remaining: 3.17s
# 137:	learn: 0.0395929	total: 505ms	remaining: 3.16s
# 138:	learn: 0.0395678	total: 508ms	remaining: 3.15s
# 139:	learn: 0.0395068	total: 511ms	remaining: 3.14s
# 140:	learn: 0.0394290	total: 513ms	remaining: 3.13s
# 141:	learn: 0.0393671	total: 516ms	remaining: 3.12s
# 142:	learn: 0.0392958	total: 519ms	remaining: 3.11s
# 143:	learn: 0.0392357	total: 521ms	remaining: 3.1s
# 144:	learn: 0.0391807	total: 524ms	remaining: 3.09s
# 145:	learn: 0.0391346	total: 527ms	remaining: 3.08s
# 146:	learn: 0.0390980	total: 529ms	remaining: 3.07s
# 147:	learn: 0.0390065	total: 532ms	remaining: 3.06s
# 148:	learn: 0.0389708	total: 534ms	remaining: 3.05s
# 149:	learn: 0.0389407	total: 537ms	remaining: 3.04s
# 150:	learn: 0.0388496	total: 539ms	remaining: 3.03s
# 151:	learn: 0.0387793	total: 542ms	remaining: 3.02s
# 152:	learn: 0.0387105	total: 544ms	remaining: 3.01s
# 153:	learn: 0.0386776	total: 547ms	remaining: 3s
# 154:	learn: 0.0386452	total: 549ms	remaining: 3s
# 155:	learn: 0.0385909	total: 552ms	remaining: 2.99s
# 156:	learn: 0.0385231	total: 555ms	remaining: 2.98s
# 157:	learn: 0.0384617	total: 557ms	remaining: 2.97s
# 158:	learn: 0.0384276	total: 560ms	remaining: 2.96s
# 159:	learn: 0.0383880	total: 563ms	remaining: 2.95s
# 160:	learn: 0.0383398	total: 565ms	remaining: 2.94s
# 161:	learn: 0.0382808	total: 568ms	remaining: 2.94s
# 162:	learn: 0.0382289	total: 570ms	remaining: 2.93s
# 163:	learn: 0.0381900	total: 573ms	remaining: 2.92s
# 164:	learn: 0.0381500	total: 576ms	remaining: 2.92s
# 165:	learn: 0.0381005	total: 579ms	remaining: 2.91s
# 166:	learn: 0.0380609	total: 582ms	remaining: 2.9s
# 167:	learn: 0.0380130	total: 584ms	remaining: 2.89s
# 168:	learn: 0.0379760	total: 587ms	remaining: 2.88s
# 169:	learn: 0.0379425	total: 589ms	remaining: 2.88s
# 170:	learn: 0.0379137	total: 592ms	remaining: 2.87s
# 171:	learn: 0.0378943	total: 595ms	remaining: 2.86s
# 172:	learn: 0.0378636	total: 597ms	remaining: 2.86s
# 173:	learn: 0.0378223	total: 600ms	remaining: 2.85s
# 174:	learn: 0.0377906	total: 603ms	remaining: 2.84s
# 175:	learn: 0.0377433	total: 605ms	remaining: 2.83s
# 176:	learn: 0.0377017	total: 608ms	remaining: 2.82s
# 177:	learn: 0.0376620	total: 610ms	remaining: 2.82s
# 178:	learn: 0.0376416	total: 613ms	remaining: 2.81s
# 179:	learn: 0.0375967	total: 615ms	remaining: 2.8s
# 180:	learn: 0.0375449	total: 618ms	remaining: 2.8s
# 181:	learn: 0.0375033	total: 621ms	remaining: 2.79s
# 182:	learn: 0.0374818	total: 623ms	remaining: 2.78s
# 183:	learn: 0.0374464	total: 626ms	remaining: 2.78s
# 184:	learn: 0.0373989	total: 629ms	remaining: 2.77s
# 185:	learn: 0.0373647	total: 632ms	remaining: 2.76s
# 186:	learn: 0.0373155	total: 634ms	remaining: 2.76s
# 187:	learn: 0.0372607	total: 637ms	remaining: 2.75s
# 188:	learn: 0.0372299	total: 639ms	remaining: 2.74s
# 189:	learn: 0.0371842	total: 642ms	remaining: 2.74s
# 190:	learn: 0.0371283	total: 645ms	remaining: 2.73s
# 191:	learn: 0.0370987	total: 647ms	remaining: 2.72s
# 192:	learn: 0.0370605	total: 650ms	remaining: 2.72s
# 193:	learn: 0.0370081	total: 652ms	remaining: 2.71s
# 194:	learn: 0.0369481	total: 655ms	remaining: 2.7s
# 195:	learn: 0.0368968	total: 658ms	remaining: 2.7s
# 196:	learn: 0.0368301	total: 660ms	remaining: 2.69s
# 197:	learn: 0.0367876	total: 663ms	remaining: 2.69s
# 198:	learn: 0.0367466	total: 666ms	remaining: 2.68s
# 199:	learn: 0.0366899	total: 668ms	remaining: 2.67s
# 200:	learn: 0.0366627	total: 671ms	remaining: 2.67s
# 201:	learn: 0.0366310	total: 674ms	remaining: 2.66s
# 202:	learn: 0.0365947	total: 677ms	remaining: 2.66s
# 203:	learn: 0.0365354	total: 680ms	remaining: 2.65s
# 204:	learn: 0.0365060	total: 682ms	remaining: 2.65s
# 205:	learn: 0.0364737	total: 685ms	remaining: 2.64s
# 206:	learn: 0.0364152	total: 688ms	remaining: 2.63s
# 207:	learn: 0.0363912	total: 691ms	remaining: 2.63s
# 208:	learn: 0.0363637	total: 694ms	remaining: 2.62s
# 209:	learn: 0.0363114	total: 696ms	remaining: 2.62s
# 210:	learn: 0.0362702	total: 699ms	remaining: 2.61s
# 211:	learn: 0.0362379	total: 701ms	remaining: 2.6s
# 212:	learn: 0.0361991	total: 703ms	remaining: 2.6s
# 213:	learn: 0.0361718	total: 706ms	remaining: 2.59s
# 214:	learn: 0.0361342	total: 709ms	remaining: 2.59s
# 215:	learn: 0.0360928	total: 711ms	remaining: 2.58s
# 216:	learn: 0.0360438	total: 714ms	remaining: 2.58s
# 217:	learn: 0.0359995	total: 716ms	remaining: 2.57s
# 218:	learn: 0.0359704	total: 719ms	remaining: 2.56s
# 219:	learn: 0.0359376	total: 721ms	remaining: 2.56s
# 220:	learn: 0.0359041	total: 724ms	remaining: 2.55s
# 221:	learn: 0.0358561	total: 727ms	remaining: 2.55s
# 222:	learn: 0.0358162	total: 729ms	remaining: 2.54s
# 223:	learn: 0.0357780	total: 732ms	remaining: 2.54s
# 224:	learn: 0.0357372	total: 735ms	remaining: 2.53s
# 225:	learn: 0.0357079	total: 737ms	remaining: 2.52s
# 226:	learn: 0.0356821	total: 740ms	remaining: 2.52s
# 227:	learn: 0.0356389	total: 742ms	remaining: 2.51s
# 228:	learn: 0.0356014	total: 745ms	remaining: 2.51s
# 229:	learn: 0.0355678	total: 747ms	remaining: 2.5s
# 230:	learn: 0.0355242	total: 750ms	remaining: 2.5s
# 231:	learn: 0.0354752	total: 753ms	remaining: 2.49s
# 232:	learn: 0.0354457	total: 755ms	remaining: 2.49s
# 233:	learn: 0.0354041	total: 758ms	remaining: 2.48s
# 234:	learn: 0.0353520	total: 761ms	remaining: 2.48s
# 235:	learn: 0.0353263	total: 763ms	remaining: 2.47s
# 236:	learn: 0.0352933	total: 766ms	remaining: 2.46s
# 237:	learn: 0.0352457	total: 768ms	remaining: 2.46s
# 238:	learn: 0.0352058	total: 771ms	remaining: 2.45s
# 239:	learn: 0.0351811	total: 773ms	remaining: 2.45s
# 240:	learn: 0.0351439	total: 776ms	remaining: 2.44s
# 241:	learn: 0.0351009	total: 779ms	remaining: 2.44s
# 242:	learn: 0.0350697	total: 781ms	remaining: 2.43s
# 243:	learn: 0.0350438	total: 784ms	remaining: 2.43s
# 244:	learn: 0.0350111	total: 786ms	remaining: 2.42s
# 245:	learn: 0.0349724	total: 789ms	remaining: 2.42s
# 246:	learn: 0.0349473	total: 792ms	remaining: 2.41s
# 247:	learn: 0.0349221	total: 794ms	remaining: 2.41s
# 248:	learn: 0.0348798	total: 797ms	remaining: 2.4s
# 249:	learn: 0.0348373	total: 800ms	remaining: 2.4s
# 250:	learn: 0.0347968	total: 802ms	remaining: 2.39s
# 251:	learn: 0.0347577	total: 805ms	remaining: 2.39s
# 252:	learn: 0.0347326	total: 808ms	remaining: 2.38s
# 253:	learn: 0.0347126	total: 810ms	remaining: 2.38s
# 254:	learn: 0.0346813	total: 813ms	remaining: 2.38s
# 255:	learn: 0.0346430	total: 816ms	remaining: 2.37s
# 256:	learn: 0.0346173	total: 818ms	remaining: 2.37s
# 257:	learn: 0.0345806	total: 821ms	remaining: 2.36s
# 258:	learn: 0.0345548	total: 824ms	remaining: 2.36s
# 259:	learn: 0.0344890	total: 827ms	remaining: 2.35s
# 260:	learn: 0.0344637	total: 830ms	remaining: 2.35s
# 261:	learn: 0.0344474	total: 833ms	remaining: 2.35s
# 262:	learn: 0.0344187	total: 836ms	remaining: 2.34s
# 263:	learn: 0.0343732	total: 839ms	remaining: 2.34s
# 264:	learn: 0.0343205	total: 842ms	remaining: 2.34s
# 265:	learn: 0.0342931	total: 845ms	remaining: 2.33s
# 266:	learn: 0.0342712	total: 848ms	remaining: 2.33s
# 267:	learn: 0.0342497	total: 851ms	remaining: 2.33s
# 268:	learn: 0.0342159	total: 854ms	remaining: 2.32s
# 269:	learn: 0.0341775	total: 857ms	remaining: 2.32s
# 270:	learn: 0.0341556	total: 860ms	remaining: 2.31s
# 271:	learn: 0.0340948	total: 863ms	remaining: 2.31s
# 272:	learn: 0.0340661	total: 866ms	remaining: 2.31s
# 273:	learn: 0.0340451	total: 869ms	remaining: 2.3s
# 274:	learn: 0.0340142	total: 871ms	remaining: 2.3s
# 275:	learn: 0.0339586	total: 874ms	remaining: 2.29s
# 276:	learn: 0.0339108	total: 876ms	remaining: 2.29s
# 277:	learn: 0.0338922	total: 879ms	remaining: 2.28s
# 278:	learn: 0.0338638	total: 881ms	remaining: 2.28s
# 279:	learn: 0.0338322	total: 884ms	remaining: 2.27s
# 280:	learn: 0.0337986	total: 887ms	remaining: 2.27s
# 281:	learn: 0.0337702	total: 889ms	remaining: 2.26s
# 282:	learn: 0.0337284	total: 892ms	remaining: 2.26s
# 283:	learn: 0.0336961	total: 895ms	remaining: 2.25s
# 284:	learn: 0.0336653	total: 897ms	remaining: 2.25s
# 285:	learn: 0.0336274	total: 900ms	remaining: 2.25s
# 286:	learn: 0.0335848	total: 902ms	remaining: 2.24s
# 287:	learn: 0.0335614	total: 905ms	remaining: 2.24s
# 288:	learn: 0.0335395	total: 907ms	remaining: 2.23s
# 289:	learn: 0.0334928	total: 910ms	remaining: 2.23s
# 290:	learn: 0.0334611	total: 912ms	remaining: 2.22s
# 291:	learn: 0.0334268	total: 915ms	remaining: 2.22s
# 292:	learn: 0.0333770	total: 918ms	remaining: 2.21s
# 293:	learn: 0.0333538	total: 920ms	remaining: 2.21s
# 294:	learn: 0.0333289	total: 923ms	remaining: 2.21s
# 295:	learn: 0.0333044	total: 925ms	remaining: 2.2s
# 296:	learn: 0.0332731	total: 928ms	remaining: 2.2s
# 297:	learn: 0.0332499	total: 931ms	remaining: 2.19s
# 298:	learn: 0.0332113	total: 933ms	remaining: 2.19s
# 299:	learn: 0.0331758	total: 936ms	remaining: 2.18s
# 300:	learn: 0.0331548	total: 938ms	remaining: 2.18s
# 301:	learn: 0.0331318	total: 941ms	remaining: 2.17s
# 302:	learn: 0.0331055	total: 943ms	remaining: 2.17s
# 303:	learn: 0.0330781	total: 946ms	remaining: 2.17s
# 304:	learn: 0.0330533	total: 948ms	remaining: 2.16s
# 305:	learn: 0.0330178	total: 951ms	remaining: 2.16s
# 306:	learn: 0.0329721	total: 954ms	remaining: 2.15s
# 307:	learn: 0.0329569	total: 956ms	remaining: 2.15s
# 308:	learn: 0.0329357	total: 959ms	remaining: 2.14s
# 309:	learn: 0.0329062	total: 961ms	remaining: 2.14s
# 310:	learn: 0.0328610	total: 964ms	remaining: 2.14s
# 311:	learn: 0.0328432	total: 967ms	remaining: 2.13s
# 312:	learn: 0.0328232	total: 970ms	remaining: 2.13s
# 313:	learn: 0.0328090	total: 972ms	remaining: 2.12s
# 314:	learn: 0.0327808	total: 975ms	remaining: 2.12s
# 315:	learn: 0.0327335	total: 978ms	remaining: 2.12s
# 316:	learn: 0.0326920	total: 981ms	remaining: 2.11s
# 317:	learn: 0.0326545	total: 983ms	remaining: 2.11s
# 318:	learn: 0.0326248	total: 986ms	remaining: 2.1s
# 319:	learn: 0.0325878	total: 989ms	remaining: 2.1s
# 320:	learn: 0.0325606	total: 991ms	remaining: 2.1s
# 321:	learn: 0.0325340	total: 994ms	remaining: 2.09s
# 322:	learn: 0.0324968	total: 997ms	remaining: 2.09s
# 323:	learn: 0.0324773	total: 999ms	remaining: 2.08s
# 324:	learn: 0.0324472	total: 1s	remaining: 2.08s
# 325:	learn: 0.0324165	total: 1s	remaining: 2.08s
# 326:	learn: 0.0323859	total: 1.01s	remaining: 2.07s
# 327:	learn: 0.0323357	total: 1.01s	remaining: 2.07s
# 328:	learn: 0.0323169	total: 1.01s	remaining: 2.07s
# 329:	learn: 0.0322923	total: 1.02s	remaining: 2.06s
# 330:	learn: 0.0322630	total: 1.02s	remaining: 2.06s
# 331:	learn: 0.0322272	total: 1.02s	remaining: 2.06s
# 332:	learn: 0.0321849	total: 1.02s	remaining: 2.05s
# 333:	learn: 0.0321528	total: 1.03s	remaining: 2.05s
# 334:	learn: 0.0321324	total: 1.03s	remaining: 2.04s
# 335:	learn: 0.0321114	total: 1.03s	remaining: 2.04s
# 336:	learn: 0.0320932	total: 1.03s	remaining: 2.04s
# 337:	learn: 0.0320594	total: 1.04s	remaining: 2.03s
# 338:	learn: 0.0320404	total: 1.04s	remaining: 2.03s
# 339:	learn: 0.0320013	total: 1.04s	remaining: 2.03s
# 340:	learn: 0.0319381	total: 1.05s	remaining: 2.02s
# 341:	learn: 0.0319180	total: 1.05s	remaining: 2.02s
# 342:	learn: 0.0319004	total: 1.05s	remaining: 2.02s
# 343:	learn: 0.0318653	total: 1.05s	remaining: 2.01s
# 344:	learn: 0.0318459	total: 1.06s	remaining: 2.01s
# 345:	learn: 0.0318131	total: 1.06s	remaining: 2s
# 346:	learn: 0.0317988	total: 1.06s	remaining: 2s
# 347:	learn: 0.0317769	total: 1.06s	remaining: 2s
# 348:	learn: 0.0317533	total: 1.07s	remaining: 1.99s
# 349:	learn: 0.0317081	total: 1.07s	remaining: 1.99s
# 350:	learn: 0.0316905	total: 1.07s	remaining: 1.99s
# 351:	learn: 0.0316559	total: 1.08s	remaining: 1.98s
# 352:	learn: 0.0316115	total: 1.08s	remaining: 1.98s
# 353:	learn: 0.0315974	total: 1.08s	remaining: 1.98s
# 354:	learn: 0.0315674	total: 1.09s	remaining: 1.98s
# 355:	learn: 0.0315522	total: 1.09s	remaining: 1.97s
# 356:	learn: 0.0315270	total: 1.09s	remaining: 1.97s
# 357:	learn: 0.0314838	total: 1.1s	remaining: 1.97s
# 358:	learn: 0.0314600	total: 1.1s	remaining: 1.96s
# 359:	learn: 0.0314257	total: 1.1s	remaining: 1.96s
# 360:	learn: 0.0313972	total: 1.11s	remaining: 1.96s
# 361:	learn: 0.0313694	total: 1.11s	remaining: 1.95s
# 362:	learn: 0.0313408	total: 1.11s	remaining: 1.95s
# 363:	learn: 0.0313048	total: 1.11s	remaining: 1.95s
# 364:	learn: 0.0312734	total: 1.12s	remaining: 1.95s
# 365:	learn: 0.0312357	total: 1.12s	remaining: 1.94s
# 366:	learn: 0.0312000	total: 1.12s	remaining: 1.94s
# 367:	learn: 0.0311743	total: 1.13s	remaining: 1.94s
# 368:	learn: 0.0311336	total: 1.13s	remaining: 1.93s
# 369:	learn: 0.0311240	total: 1.13s	remaining: 1.93s
# 370:	learn: 0.0310967	total: 1.14s	remaining: 1.93s
# 371:	learn: 0.0310655	total: 1.14s	remaining: 1.92s
# 372:	learn: 0.0310501	total: 1.14s	remaining: 1.92s
# 373:	learn: 0.0310249	total: 1.14s	remaining: 1.92s
# 374:	learn: 0.0309921	total: 1.15s	remaining: 1.91s
# 375:	learn: 0.0309622	total: 1.15s	remaining: 1.91s
# 376:	learn: 0.0309471	total: 1.15s	remaining: 1.9s
# 377:	learn: 0.0309228	total: 1.16s	remaining: 1.9s
# 378:	learn: 0.0308908	total: 1.16s	remaining: 1.9s
# 379:	learn: 0.0308529	total: 1.16s	remaining: 1.89s
# 380:	learn: 0.0308292	total: 1.16s	remaining: 1.89s
# 381:	learn: 0.0308035	total: 1.17s	remaining: 1.89s
# 382:	learn: 0.0307690	total: 1.17s	remaining: 1.88s
# 383:	learn: 0.0307260	total: 1.17s	remaining: 1.88s
# 384:	learn: 0.0307061	total: 1.17s	remaining: 1.88s
# 385:	learn: 0.0306804	total: 1.18s	remaining: 1.87s
# 386:	learn: 0.0306580	total: 1.18s	remaining: 1.87s
# 387:	learn: 0.0306476	total: 1.18s	remaining: 1.87s
# 388:	learn: 0.0306291	total: 1.19s	remaining: 1.86s
# 389:	learn: 0.0306149	total: 1.19s	remaining: 1.86s
# 390:	learn: 0.0305998	total: 1.19s	remaining: 1.86s
# 391:	learn: 0.0305846	total: 1.19s	remaining: 1.85s
# 392:	learn: 0.0305599	total: 1.2s	remaining: 1.85s
# 393:	learn: 0.0305169	total: 1.2s	remaining: 1.85s
# 394:	learn: 0.0304873	total: 1.2s	remaining: 1.84s
# 395:	learn: 0.0304664	total: 1.21s	remaining: 1.84s
# 396:	learn: 0.0304441	total: 1.21s	remaining: 1.84s
# 397:	learn: 0.0304162	total: 1.21s	remaining: 1.83s
# 398:	learn: 0.0303907	total: 1.22s	remaining: 1.83s
# 399:	learn: 0.0303683	total: 1.22s	remaining: 1.83s
# 400:	learn: 0.0303474	total: 1.22s	remaining: 1.82s
# 401:	learn: 0.0303118	total: 1.22s	remaining: 1.82s
# 402:	learn: 0.0302911	total: 1.23s	remaining: 1.81s
# 403:	learn: 0.0302717	total: 1.23s	remaining: 1.81s
# 404:	learn: 0.0302472	total: 1.23s	remaining: 1.81s
# 405:	learn: 0.0302258	total: 1.23s	remaining: 1.81s
# 406:	learn: 0.0301899	total: 1.24s	remaining: 1.8s
# 407:	learn: 0.0301582	total: 1.24s	remaining: 1.8s
# 408:	learn: 0.0301389	total: 1.24s	remaining: 1.79s
# 409:	learn: 0.0301201	total: 1.25s	remaining: 1.79s
# 410:	learn: 0.0300984	total: 1.25s	remaining: 1.79s
# 411:	learn: 0.0300701	total: 1.25s	remaining: 1.78s
# 412:	learn: 0.0300383	total: 1.25s	remaining: 1.78s
# 413:	learn: 0.0300178	total: 1.26s	remaining: 1.78s
# 414:	learn: 0.0299999	total: 1.26s	remaining: 1.77s
# 415:	learn: 0.0299780	total: 1.26s	remaining: 1.77s
# 416:	learn: 0.0299507	total: 1.26s	remaining: 1.77s
# 417:	learn: 0.0299138	total: 1.27s	remaining: 1.76s
# 418:	learn: 0.0298943	total: 1.27s	remaining: 1.76s
# 419:	learn: 0.0298821	total: 1.27s	remaining: 1.76s
# 420:	learn: 0.0298438	total: 1.27s	remaining: 1.75s
# 421:	learn: 0.0298115	total: 1.28s	remaining: 1.75s
# 422:	learn: 0.0297870	total: 1.28s	remaining: 1.75s
# 423:	learn: 0.0297728	total: 1.28s	remaining: 1.74s
# 424:	learn: 0.0297325	total: 1.28s	remaining: 1.74s
# 425:	learn: 0.0297235	total: 1.29s	remaining: 1.73s
# 426:	learn: 0.0297061	total: 1.29s	remaining: 1.73s
# 427:	learn: 0.0296908	total: 1.29s	remaining: 1.73s
# 428:	learn: 0.0296770	total: 1.29s	remaining: 1.72s
# 429:	learn: 0.0296610	total: 1.3s	remaining: 1.72s
# 430:	learn: 0.0296354	total: 1.3s	remaining: 1.72s
# 431:	learn: 0.0296171	total: 1.3s	remaining: 1.71s
# 432:	learn: 0.0295945	total: 1.31s	remaining: 1.71s
# 433:	learn: 0.0295807	total: 1.31s	remaining: 1.71s
# 434:	learn: 0.0295539	total: 1.31s	remaining: 1.7s
# 435:	learn: 0.0295379	total: 1.31s	remaining: 1.7s
# 436:	learn: 0.0295096	total: 1.32s	remaining: 1.7s
# 437:	learn: 0.0294953	total: 1.32s	remaining: 1.69s
# 438:	learn: 0.0294497	total: 1.32s	remaining: 1.69s
# 439:	learn: 0.0294261	total: 1.32s	remaining: 1.69s
# 440:	learn: 0.0294025	total: 1.33s	remaining: 1.68s
# 441:	learn: 0.0293762	total: 1.33s	remaining: 1.68s
# 442:	learn: 0.0293584	total: 1.33s	remaining: 1.68s
# 443:	learn: 0.0293338	total: 1.34s	remaining: 1.67s
# 444:	learn: 0.0293099	total: 1.34s	remaining: 1.67s
# 445:	learn: 0.0292976	total: 1.34s	remaining: 1.67s
# 446:	learn: 0.0292711	total: 1.34s	remaining: 1.66s
# 447:	learn: 0.0292371	total: 1.35s	remaining: 1.66s
# 448:	learn: 0.0292189	total: 1.35s	remaining: 1.66s
# 449:	learn: 0.0291869	total: 1.35s	remaining: 1.65s
# 450:	learn: 0.0291623	total: 1.36s	remaining: 1.65s
# 451:	learn: 0.0291442	total: 1.36s	remaining: 1.65s
# 452:	learn: 0.0291281	total: 1.36s	remaining: 1.64s
# 453:	learn: 0.0291122	total: 1.36s	remaining: 1.64s
# 454:	learn: 0.0290879	total: 1.37s	remaining: 1.64s
# 455:	learn: 0.0290488	total: 1.37s	remaining: 1.63s
# 456:	learn: 0.0290237	total: 1.37s	remaining: 1.63s
# 457:	learn: 0.0289934	total: 1.38s	remaining: 1.63s
# 458:	learn: 0.0289693	total: 1.38s	remaining: 1.62s
# 459:	learn: 0.0289456	total: 1.38s	remaining: 1.62s
# 460:	learn: 0.0289195	total: 1.38s	remaining: 1.62s
# 461:	learn: 0.0288881	total: 1.39s	remaining: 1.61s
# 462:	learn: 0.0288634	total: 1.39s	remaining: 1.61s
# 463:	learn: 0.0288446	total: 1.39s	remaining: 1.61s
# 464:	learn: 0.0288252	total: 1.4s	remaining: 1.6s
# 465:	learn: 0.0288080	total: 1.4s	remaining: 1.6s
# 466:	learn: 0.0287904	total: 1.4s	remaining: 1.6s
# 467:	learn: 0.0287578	total: 1.4s	remaining: 1.59s
# 468:	learn: 0.0287348	total: 1.41s	remaining: 1.59s
# 469:	learn: 0.0287096	total: 1.41s	remaining: 1.59s
# 470:	learn: 0.0286881	total: 1.41s	remaining: 1.58s
# 471:	learn: 0.0286638	total: 1.41s	remaining: 1.58s
# 472:	learn: 0.0286498	total: 1.42s	remaining: 1.58s
# 473:	learn: 0.0286362	total: 1.42s	remaining: 1.57s
# 474:	learn: 0.0286019	total: 1.42s	remaining: 1.57s
# 475:	learn: 0.0285817	total: 1.42s	remaining: 1.57s
# 476:	learn: 0.0285592	total: 1.43s	remaining: 1.56s
# 477:	learn: 0.0285464	total: 1.43s	remaining: 1.56s
# 478:	learn: 0.0285275	total: 1.43s	remaining: 1.56s
# 479:	learn: 0.0285159	total: 1.44s	remaining: 1.55s
# 480:	learn: 0.0285035	total: 1.44s	remaining: 1.55s
# 481:	learn: 0.0284759	total: 1.44s	remaining: 1.55s
# 482:	learn: 0.0284601	total: 1.44s	remaining: 1.54s
# 483:	learn: 0.0284479	total: 1.45s	remaining: 1.54s
# 484:	learn: 0.0284322	total: 1.45s	remaining: 1.54s
# 485:	learn: 0.0284071	total: 1.45s	remaining: 1.53s
# 486:	learn: 0.0283901	total: 1.45s	remaining: 1.53s
# 487:	learn: 0.0283728	total: 1.46s	remaining: 1.53s
# 488:	learn: 0.0283593	total: 1.46s	remaining: 1.52s
# 489:	learn: 0.0283337	total: 1.46s	remaining: 1.52s
# 490:	learn: 0.0282973	total: 1.47s	remaining: 1.52s
# 491:	learn: 0.0282602	total: 1.47s	remaining: 1.51s
# 492:	learn: 0.0282482	total: 1.47s	remaining: 1.51s
# 493:	learn: 0.0282357	total: 1.47s	remaining: 1.51s
# 494:	learn: 0.0282244	total: 1.48s	remaining: 1.51s
# 495:	learn: 0.0282038	total: 1.48s	remaining: 1.5s
# 496:	learn: 0.0281777	total: 1.48s	remaining: 1.5s
# 497:	learn: 0.0281544	total: 1.48s	remaining: 1.5s
# 498:	learn: 0.0281372	total: 1.49s	remaining: 1.49s
# 499:	learn: 0.0281172	total: 1.49s	remaining: 1.49s
# 500:	learn: 0.0280868	total: 1.49s	remaining: 1.49s
# 501:	learn: 0.0280720	total: 1.5s	remaining: 1.48s
# 502:	learn: 0.0280516	total: 1.5s	remaining: 1.48s
# 503:	learn: 0.0280333	total: 1.5s	remaining: 1.48s
# 504:	learn: 0.0280040	total: 1.5s	remaining: 1.47s
# 505:	learn: 0.0279806	total: 1.51s	remaining: 1.47s
# 506:	learn: 0.0279601	total: 1.51s	remaining: 1.47s
# 507:	learn: 0.0279451	total: 1.51s	remaining: 1.46s
# 508:	learn: 0.0279180	total: 1.51s	remaining: 1.46s
# 509:	learn: 0.0279017	total: 1.52s	remaining: 1.46s
# 510:	learn: 0.0278724	total: 1.52s	remaining: 1.45s
# 511:	learn: 0.0278450	total: 1.52s	remaining: 1.45s
# 512:	learn: 0.0278067	total: 1.53s	remaining: 1.45s
# 513:	learn: 0.0277957	total: 1.53s	remaining: 1.45s
# 514:	learn: 0.0277818	total: 1.53s	remaining: 1.44s
# 515:	learn: 0.0277714	total: 1.53s	remaining: 1.44s
# 516:	learn: 0.0277534	total: 1.54s	remaining: 1.44s
# 517:	learn: 0.0277385	total: 1.54s	remaining: 1.43s
# 518:	learn: 0.0277185	total: 1.54s	remaining: 1.43s
# 519:	learn: 0.0277019	total: 1.54s	remaining: 1.43s
# 520:	learn: 0.0276836	total: 1.55s	remaining: 1.42s
# 521:	learn: 0.0276652	total: 1.55s	remaining: 1.42s
# 522:	learn: 0.0276490	total: 1.55s	remaining: 1.42s
# 523:	learn: 0.0276202	total: 1.55s	remaining: 1.41s
# 524:	learn: 0.0276080	total: 1.56s	remaining: 1.41s
# 525:	learn: 0.0275835	total: 1.56s	remaining: 1.41s
# 526:	learn: 0.0275764	total: 1.56s	remaining: 1.4s
# 527:	learn: 0.0275579	total: 1.57s	remaining: 1.4s
# 528:	learn: 0.0275275	total: 1.57s	remaining: 1.4s
# 529:	learn: 0.0275023	total: 1.57s	remaining: 1.39s
# 530:	learn: 0.0274771	total: 1.57s	remaining: 1.39s
# 531:	learn: 0.0274643	total: 1.58s	remaining: 1.39s
# 532:	learn: 0.0274437	total: 1.58s	remaining: 1.38s
# 533:	learn: 0.0274229	total: 1.58s	remaining: 1.38s
# 534:	learn: 0.0274112	total: 1.58s	remaining: 1.38s
# 535:	learn: 0.0273940	total: 1.59s	remaining: 1.37s
# 536:	learn: 0.0273817	total: 1.59s	remaining: 1.37s
# 537:	learn: 0.0273655	total: 1.59s	remaining: 1.37s
# 538:	learn: 0.0273469	total: 1.59s	remaining: 1.36s
# 539:	learn: 0.0273239	total: 1.6s	remaining: 1.36s
# 540:	learn: 0.0273081	total: 1.6s	remaining: 1.36s
# 541:	learn: 0.0272772	total: 1.6s	remaining: 1.35s
# 542:	learn: 0.0272518	total: 1.61s	remaining: 1.35s
# 543:	learn: 0.0272378	total: 1.61s	remaining: 1.35s
# 544:	learn: 0.0272283	total: 1.61s	remaining: 1.34s
# 545:	learn: 0.0272134	total: 1.61s	remaining: 1.34s
# 546:	learn: 0.0271820	total: 1.62s	remaining: 1.34s
# 547:	learn: 0.0271700	total: 1.62s	remaining: 1.33s
# 548:	learn: 0.0271517	total: 1.62s	remaining: 1.33s
# 549:	learn: 0.0271400	total: 1.62s	remaining: 1.33s
# 550:	learn: 0.0271158	total: 1.63s	remaining: 1.32s
# 551:	learn: 0.0271018	total: 1.63s	remaining: 1.32s
# 552:	learn: 0.0270814	total: 1.63s	remaining: 1.32s
# 553:	learn: 0.0270636	total: 1.64s	remaining: 1.32s
# 554:	learn: 0.0270484	total: 1.64s	remaining: 1.31s
# 555:	learn: 0.0270258	total: 1.64s	remaining: 1.31s
# 556:	learn: 0.0270105	total: 1.64s	remaining: 1.31s
# 557:	learn: 0.0269922	total: 1.65s	remaining: 1.3s
# 558:	learn: 0.0269733	total: 1.65s	remaining: 1.3s
# 559:	learn: 0.0269446	total: 1.65s	remaining: 1.3s
# 560:	learn: 0.0269136	total: 1.66s	remaining: 1.29s
# 561:	learn: 0.0269060	total: 1.66s	remaining: 1.29s
# 562:	learn: 0.0268959	total: 1.66s	remaining: 1.29s
# 563:	learn: 0.0268793	total: 1.66s	remaining: 1.29s
# 564:	learn: 0.0268671	total: 1.67s	remaining: 1.28s
# 565:	learn: 0.0268242	total: 1.67s	remaining: 1.28s
# 566:	learn: 0.0268007	total: 1.67s	remaining: 1.28s
# 567:	learn: 0.0267679	total: 1.67s	remaining: 1.27s
# 568:	learn: 0.0267588	total: 1.68s	remaining: 1.27s
# 569:	learn: 0.0267430	total: 1.68s	remaining: 1.27s
# 570:	learn: 0.0267310	total: 1.68s	remaining: 1.26s
# 571:	learn: 0.0267182	total: 1.69s	remaining: 1.26s
# 572:	learn: 0.0267014	total: 1.69s	remaining: 1.26s
# 573:	learn: 0.0266764	total: 1.69s	remaining: 1.25s
# 574:	learn: 0.0266479	total: 1.69s	remaining: 1.25s
# 575:	learn: 0.0266232	total: 1.7s	remaining: 1.25s
# 576:	learn: 0.0266086	total: 1.7s	remaining: 1.25s
# 577:	learn: 0.0265920	total: 1.7s	remaining: 1.24s
# 578:	learn: 0.0265851	total: 1.7s	remaining: 1.24s
# 579:	learn: 0.0265599	total: 1.71s	remaining: 1.24s
# 580:	learn: 0.0265366	total: 1.71s	remaining: 1.23s
# 581:	learn: 0.0265185	total: 1.71s	remaining: 1.23s
# 582:	learn: 0.0264940	total: 1.72s	remaining: 1.23s
# 583:	learn: 0.0264716	total: 1.72s	remaining: 1.22s
# 584:	learn: 0.0264615	total: 1.72s	remaining: 1.22s
# 585:	learn: 0.0264389	total: 1.72s	remaining: 1.22s
# 586:	learn: 0.0264142	total: 1.73s	remaining: 1.22s
# 587:	learn: 0.0263952	total: 1.73s	remaining: 1.21s
# 588:	learn: 0.0263656	total: 1.73s	remaining: 1.21s
# 589:	learn: 0.0263480	total: 1.74s	remaining: 1.21s
# 590:	learn: 0.0263348	total: 1.74s	remaining: 1.2s
# 591:	learn: 0.0263266	total: 1.74s	remaining: 1.2s
# 592:	learn: 0.0262933	total: 1.74s	remaining: 1.2s
# 593:	learn: 0.0262789	total: 1.75s	remaining: 1.19s
# 594:	learn: 0.0262603	total: 1.75s	remaining: 1.19s
# 595:	learn: 0.0262369	total: 1.75s	remaining: 1.19s
# 596:	learn: 0.0262193	total: 1.75s	remaining: 1.18s
# 597:	learn: 0.0262124	total: 1.76s	remaining: 1.18s
# 598:	learn: 0.0261906	total: 1.76s	remaining: 1.18s
# 599:	learn: 0.0261816	total: 1.76s	remaining: 1.17s
# 600:	learn: 0.0261610	total: 1.76s	remaining: 1.17s
# 601:	learn: 0.0261432	total: 1.77s	remaining: 1.17s
# 602:	learn: 0.0261352	total: 1.77s	remaining: 1.17s
# 603:	learn: 0.0261258	total: 1.77s	remaining: 1.16s
# 604:	learn: 0.0260956	total: 1.77s	remaining: 1.16s
# 605:	learn: 0.0260643	total: 1.78s	remaining: 1.16s
# 606:	learn: 0.0260575	total: 1.78s	remaining: 1.15s
# 607:	learn: 0.0260428	total: 1.78s	remaining: 1.15s
# 608:	learn: 0.0260368	total: 1.79s	remaining: 1.15s
# 609:	learn: 0.0260164	total: 1.79s	remaining: 1.14s
# 610:	learn: 0.0259949	total: 1.79s	remaining: 1.14s
# 611:	learn: 0.0259771	total: 1.79s	remaining: 1.14s
# 612:	learn: 0.0259432	total: 1.8s	remaining: 1.13s
# 613:	learn: 0.0259294	total: 1.8s	remaining: 1.13s
# 614:	learn: 0.0259107	total: 1.8s	remaining: 1.13s
# 615:	learn: 0.0258986	total: 1.8s	remaining: 1.12s
# 616:	learn: 0.0258792	total: 1.81s	remaining: 1.12s
# 617:	learn: 0.0258665	total: 1.81s	remaining: 1.12s
# 618:	learn: 0.0258440	total: 1.81s	remaining: 1.11s
# 619:	learn: 0.0258344	total: 1.81s	remaining: 1.11s
# 620:	learn: 0.0258069	total: 1.82s	remaining: 1.11s
# 621:	learn: 0.0257862	total: 1.82s	remaining: 1.1s
# 622:	learn: 0.0257557	total: 1.82s	remaining: 1.1s
# 623:	learn: 0.0257375	total: 1.82s	remaining: 1.1s
# 624:	learn: 0.0257100	total: 1.83s	remaining: 1.1s
# 625:	learn: 0.0256957	total: 1.83s	remaining: 1.09s
# 626:	learn: 0.0256760	total: 1.83s	remaining: 1.09s
# 627:	learn: 0.0256670	total: 1.83s	remaining: 1.09s
# 628:	learn: 0.0256315	total: 1.84s	remaining: 1.08s
# 629:	learn: 0.0256145	total: 1.84s	remaining: 1.08s
# 630:	learn: 0.0255999	total: 1.84s	remaining: 1.08s
# 631:	learn: 0.0255928	total: 1.84s	remaining: 1.07s
# 632:	learn: 0.0255651	total: 1.85s	remaining: 1.07s
# 633:	learn: 0.0255449	total: 1.85s	remaining: 1.07s
# 634:	learn: 0.0255338	total: 1.85s	remaining: 1.06s
# 635:	learn: 0.0255174	total: 1.86s	remaining: 1.06s
# 636:	learn: 0.0255016	total: 1.86s	remaining: 1.06s
# 637:	learn: 0.0254871	total: 1.86s	remaining: 1.06s
# 638:	learn: 0.0254649	total: 1.86s	remaining: 1.05s
# 639:	learn: 0.0254367	total: 1.87s	remaining: 1.05s
# 640:	learn: 0.0254194	total: 1.87s	remaining: 1.05s
# 641:	learn: 0.0253986	total: 1.87s	remaining: 1.04s
# 642:	learn: 0.0253877	total: 1.87s	remaining: 1.04s
# 643:	learn: 0.0253771	total: 1.88s	remaining: 1.04s
# 644:	learn: 0.0253692	total: 1.88s	remaining: 1.03s
# 645:	learn: 0.0253488	total: 1.88s	remaining: 1.03s
# 646:	learn: 0.0253328	total: 1.88s	remaining: 1.03s
# 647:	learn: 0.0253196	total: 1.89s	remaining: 1.02s
# 648:	learn: 0.0253003	total: 1.89s	remaining: 1.02s
# 649:	learn: 0.0252840	total: 1.89s	remaining: 1.02s
# 650:	learn: 0.0252603	total: 1.9s	remaining: 1.02s
# 651:	learn: 0.0252387	total: 1.9s	remaining: 1.01s
# 652:	learn: 0.0252062	total: 1.9s	remaining: 1.01s
# 653:	learn: 0.0251711	total: 1.9s	remaining: 1.01s
# 654:	learn: 0.0251558	total: 1.91s	remaining: 1s
# 655:	learn: 0.0251429	total: 1.91s	remaining: 1s
# 656:	learn: 0.0251303	total: 1.91s	remaining: 998ms
# 657:	learn: 0.0251158	total: 1.91s	remaining: 995ms
# 658:	learn: 0.0251087	total: 1.92s	remaining: 992ms
# 659:	learn: 0.0251025	total: 1.92s	remaining: 989ms
# 660:	learn: 0.0250869	total: 1.92s	remaining: 986ms
# 661:	learn: 0.0250773	total: 1.92s	remaining: 983ms
# 662:	learn: 0.0250645	total: 1.93s	remaining: 980ms
# 663:	learn: 0.0250487	total: 1.93s	remaining: 977ms
# 664:	learn: 0.0250240	total: 1.93s	remaining: 974ms
# 665:	learn: 0.0250114	total: 1.94s	remaining: 971ms
# 666:	learn: 0.0249956	total: 1.94s	remaining: 967ms
# 667:	learn: 0.0249781	total: 1.94s	remaining: 964ms
# 668:	learn: 0.0249570	total: 1.94s	remaining: 961ms
# 669:	learn: 0.0249491	total: 1.95s	remaining: 958ms
# 670:	learn: 0.0249236	total: 1.95s	remaining: 955ms
# 671:	learn: 0.0249118	total: 1.95s	remaining: 952ms
# 672:	learn: 0.0248846	total: 1.95s	remaining: 949ms
# 673:	learn: 0.0248719	total: 1.96s	remaining: 946ms
# 674:	learn: 0.0248627	total: 1.96s	remaining: 943ms
# 675:	learn: 0.0248507	total: 1.96s	remaining: 940ms
# 676:	learn: 0.0248345	total: 1.96s	remaining: 937ms
# 677:	learn: 0.0248228	total: 1.97s	remaining: 934ms
# 678:	learn: 0.0248025	total: 1.97s	remaining: 931ms
# 679:	learn: 0.0247893	total: 1.97s	remaining: 928ms
# 680:	learn: 0.0247749	total: 1.97s	remaining: 925ms
# 681:	learn: 0.0247600	total: 1.98s	remaining: 922ms
# 682:	learn: 0.0247317	total: 1.98s	remaining: 919ms
# 683:	learn: 0.0247085	total: 1.98s	remaining: 916ms
# 684:	learn: 0.0246915	total: 1.99s	remaining: 913ms
# 685:	learn: 0.0246743	total: 1.99s	remaining: 910ms
# 686:	learn: 0.0246612	total: 1.99s	remaining: 907ms
# 687:	learn: 0.0246370	total: 1.99s	remaining: 904ms
# 688:	learn: 0.0246301	total: 2s	remaining: 901ms
# 689:	learn: 0.0246169	total: 2s	remaining: 898ms
# 690:	learn: 0.0246064	total: 2s	remaining: 895ms
# 691:	learn: 0.0245805	total: 2s	remaining: 892ms
# 692:	learn: 0.0245708	total: 2s	remaining: 889ms
# 693:	learn: 0.0245548	total: 2.01s	remaining: 886ms
# 694:	learn: 0.0245319	total: 2.01s	remaining: 882ms
# 695:	learn: 0.0245167	total: 2.01s	remaining: 879ms
# 696:	learn: 0.0245013	total: 2.02s	remaining: 876ms
# 697:	learn: 0.0244853	total: 2.02s	remaining: 873ms
# 698:	learn: 0.0244777	total: 2.02s	remaining: 870ms
# 699:	learn: 0.0244704	total: 2.02s	remaining: 867ms
# 700:	learn: 0.0244584	total: 2.03s	remaining: 864ms
# 701:	learn: 0.0244401	total: 2.03s	remaining: 861ms
# 702:	learn: 0.0244215	total: 2.03s	remaining: 858ms
# 703:	learn: 0.0244060	total: 2.03s	remaining: 855ms
# 704:	learn: 0.0243879	total: 2.04s	remaining: 852ms
# 705:	learn: 0.0243811	total: 2.04s	remaining: 849ms
# 706:	learn: 0.0243648	total: 2.04s	remaining: 846ms
# 707:	learn: 0.0243583	total: 2.04s	remaining: 843ms
# 708:	learn: 0.0243454	total: 2.05s	remaining: 840ms
# 709:	learn: 0.0243304	total: 2.05s	remaining: 837ms
# 710:	learn: 0.0243138	total: 2.05s	remaining: 834ms
# 711:	learn: 0.0243066	total: 2.05s	remaining: 831ms
# 712:	learn: 0.0242960	total: 2.06s	remaining: 828ms
# 713:	learn: 0.0242751	total: 2.06s	remaining: 825ms
# 714:	learn: 0.0242663	total: 2.06s	remaining: 822ms
# 715:	learn: 0.0242490	total: 2.06s	remaining: 819ms
# 716:	learn: 0.0242394	total: 2.07s	remaining: 816ms
# 717:	learn: 0.0242261	total: 2.07s	remaining: 813ms
# 718:	learn: 0.0242185	total: 2.07s	remaining: 810ms
# 719:	learn: 0.0242082	total: 2.08s	remaining: 807ms
# 720:	learn: 0.0242029	total: 2.08s	remaining: 804ms
# 721:	learn: 0.0241878	total: 2.08s	remaining: 801ms
# 722:	learn: 0.0241754	total: 2.08s	remaining: 798ms
# 723:	learn: 0.0241523	total: 2.08s	remaining: 795ms
# 724:	learn: 0.0241404	total: 2.09s	remaining: 792ms
# 725:	learn: 0.0241312	total: 2.09s	remaining: 789ms
# 726:	learn: 0.0241120	total: 2.09s	remaining: 786ms
# 727:	learn: 0.0240955	total: 2.1s	remaining: 783ms
# 728:	learn: 0.0240728	total: 2.1s	remaining: 780ms
# 729:	learn: 0.0240580	total: 2.1s	remaining: 777ms
# 730:	learn: 0.0240442	total: 2.1s	remaining: 774ms
# 731:	learn: 0.0240352	total: 2.1s	remaining: 771ms
# 732:	learn: 0.0240133	total: 2.11s	remaining: 768ms
# 733:	learn: 0.0240073	total: 2.11s	remaining: 765ms
# 734:	learn: 0.0239940	total: 2.11s	remaining: 762ms
# 735:	learn: 0.0239717	total: 2.12s	remaining: 759ms
# 736:	learn: 0.0239468	total: 2.12s	remaining: 756ms
# 737:	learn: 0.0239218	total: 2.12s	remaining: 753ms
# 738:	learn: 0.0239060	total: 2.12s	remaining: 750ms
# 739:	learn: 0.0238859	total: 2.13s	remaining: 747ms
# 740:	learn: 0.0238726	total: 2.13s	remaining: 744ms
# 741:	learn: 0.0238594	total: 2.13s	remaining: 741ms
# 742:	learn: 0.0238491	total: 2.13s	remaining: 738ms
# 743:	learn: 0.0238295	total: 2.14s	remaining: 735ms
# 744:	learn: 0.0238161	total: 2.14s	remaining: 732ms
# 745:	learn: 0.0238024	total: 2.14s	remaining: 729ms
# 746:	learn: 0.0237898	total: 2.14s	remaining: 726ms
# 747:	learn: 0.0237775	total: 2.15s	remaining: 723ms
# 748:	learn: 0.0237596	total: 2.15s	remaining: 720ms
# 749:	learn: 0.0237467	total: 2.15s	remaining: 717ms
# 750:	learn: 0.0237337	total: 2.15s	remaining: 714ms
# 751:	learn: 0.0237168	total: 2.16s	remaining: 711ms
# 752:	learn: 0.0236874	total: 2.16s	remaining: 708ms
# 753:	learn: 0.0236766	total: 2.16s	remaining: 706ms
# 754:	learn: 0.0236482	total: 2.17s	remaining: 703ms
# 755:	learn: 0.0236425	total: 2.17s	remaining: 700ms
# 756:	learn: 0.0236294	total: 2.17s	remaining: 697ms
# 757:	learn: 0.0236206	total: 2.17s	remaining: 694ms
# 758:	learn: 0.0236009	total: 2.17s	remaining: 691ms
# 759:	learn: 0.0235887	total: 2.18s	remaining: 688ms
# 760:	learn: 0.0235708	total: 2.18s	remaining: 685ms
# 761:	learn: 0.0235569	total: 2.18s	remaining: 682ms
# 762:	learn: 0.0235404	total: 2.19s	remaining: 679ms
# 763:	learn: 0.0235276	total: 2.19s	remaining: 676ms
# 764:	learn: 0.0235202	total: 2.19s	remaining: 673ms
# 765:	learn: 0.0235102	total: 2.19s	remaining: 670ms
# 766:	learn: 0.0234997	total: 2.19s	remaining: 667ms
# 767:	learn: 0.0234807	total: 2.2s	remaining: 664ms
# 768:	learn: 0.0234657	total: 2.2s	remaining: 661ms
# 769:	learn: 0.0234549	total: 2.2s	remaining: 658ms
# 770:	learn: 0.0234413	total: 2.21s	remaining: 655ms
# 771:	learn: 0.0234241	total: 2.21s	remaining: 652ms
# 772:	learn: 0.0234131	total: 2.21s	remaining: 649ms
# 773:	learn: 0.0234061	total: 2.21s	remaining: 646ms
# 774:	learn: 0.0233911	total: 2.22s	remaining: 644ms
# 775:	learn: 0.0233813	total: 2.22s	remaining: 641ms
# 776:	learn: 0.0233666	total: 2.22s	remaining: 638ms
# 777:	learn: 0.0233497	total: 2.22s	remaining: 635ms
# 778:	learn: 0.0233393	total: 2.23s	remaining: 632ms
# 779:	learn: 0.0233276	total: 2.23s	remaining: 629ms
# 780:	learn: 0.0233120	total: 2.23s	remaining: 626ms
# 781:	learn: 0.0232922	total: 2.23s	remaining: 623ms
# 782:	learn: 0.0232869	total: 2.24s	remaining: 620ms
# 783:	learn: 0.0232696	total: 2.24s	remaining: 617ms
# 784:	learn: 0.0232621	total: 2.24s	remaining: 615ms
# 785:	learn: 0.0232395	total: 2.25s	remaining: 612ms
# 786:	learn: 0.0232151	total: 2.25s	remaining: 609ms
# 787:	learn: 0.0232047	total: 2.25s	remaining: 606ms
# 788:	learn: 0.0231961	total: 2.25s	remaining: 603ms
# 789:	learn: 0.0231794	total: 2.26s	remaining: 600ms
# 790:	learn: 0.0231528	total: 2.26s	remaining: 597ms
# 791:	learn: 0.0231388	total: 2.26s	remaining: 594ms
# 792:	learn: 0.0231238	total: 2.27s	remaining: 591ms
# 793:	learn: 0.0231186	total: 2.27s	remaining: 588ms
# 794:	learn: 0.0231001	total: 2.27s	remaining: 585ms
# 795:	learn: 0.0230835	total: 2.27s	remaining: 582ms
# 796:	learn: 0.0230718	total: 2.27s	remaining: 579ms
# 797:	learn: 0.0230554	total: 2.28s	remaining: 577ms
# 798:	learn: 0.0230397	total: 2.28s	remaining: 574ms
# 799:	learn: 0.0230342	total: 2.28s	remaining: 571ms
# 800:	learn: 0.0230140	total: 2.29s	remaining: 568ms
# 801:	learn: 0.0229899	total: 2.29s	remaining: 565ms
# 802:	learn: 0.0229789	total: 2.29s	remaining: 562ms
# 803:	learn: 0.0229664	total: 2.29s	remaining: 559ms
# 804:	learn: 0.0229478	total: 2.29s	remaining: 556ms
# 805:	learn: 0.0229326	total: 2.3s	remaining: 553ms
# 806:	learn: 0.0229200	total: 2.3s	remaining: 550ms
# 807:	learn: 0.0229079	total: 2.3s	remaining: 547ms
# 808:	learn: 0.0228991	total: 2.31s	remaining: 544ms
# 809:	learn: 0.0228803	total: 2.31s	remaining: 542ms
# 810:	learn: 0.0228724	total: 2.31s	remaining: 539ms
# 811:	learn: 0.0228652	total: 2.31s	remaining: 536ms
# 812:	learn: 0.0228536	total: 2.32s	remaining: 533ms
# 813:	learn: 0.0228354	total: 2.32s	remaining: 530ms
# 814:	learn: 0.0228206	total: 2.32s	remaining: 527ms
# 815:	learn: 0.0228153	total: 2.32s	remaining: 524ms
# 816:	learn: 0.0227988	total: 2.33s	remaining: 521ms
# 817:	learn: 0.0227889	total: 2.33s	remaining: 518ms
# 818:	learn: 0.0227741	total: 2.33s	remaining: 515ms
# 819:	learn: 0.0227673	total: 2.33s	remaining: 512ms
# 820:	learn: 0.0227592	total: 2.34s	remaining: 509ms
# 821:	learn: 0.0227485	total: 2.34s	remaining: 507ms
# 822:	learn: 0.0227380	total: 2.34s	remaining: 504ms
# 823:	learn: 0.0227237	total: 2.34s	remaining: 501ms
# 824:	learn: 0.0227159	total: 2.35s	remaining: 498ms
# 825:	learn: 0.0226939	total: 2.35s	remaining: 495ms
# 826:	learn: 0.0226834	total: 2.35s	remaining: 492ms
# 827:	learn: 0.0226719	total: 2.35s	remaining: 489ms
# 828:	learn: 0.0226527	total: 2.36s	remaining: 486ms
# 829:	learn: 0.0226493	total: 2.36s	remaining: 483ms
# 830:	learn: 0.0226339	total: 2.36s	remaining: 480ms
# 831:	learn: 0.0226256	total: 2.37s	remaining: 478ms
# 832:	learn: 0.0226190	total: 2.37s	remaining: 475ms
# 833:	learn: 0.0225998	total: 2.37s	remaining: 472ms
# 834:	learn: 0.0225791	total: 2.37s	remaining: 469ms
# 835:	learn: 0.0225597	total: 2.38s	remaining: 466ms
# 836:	learn: 0.0225470	total: 2.38s	remaining: 463ms
# 837:	learn: 0.0225310	total: 2.38s	remaining: 460ms
# 838:	learn: 0.0225217	total: 2.38s	remaining: 457ms
# 839:	learn: 0.0225053	total: 2.38s	remaining: 454ms
# 840:	learn: 0.0224864	total: 2.39s	remaining: 452ms
# 841:	learn: 0.0224787	total: 2.39s	remaining: 449ms
# 842:	learn: 0.0224732	total: 2.39s	remaining: 446ms
# 843:	learn: 0.0224625	total: 2.4s	remaining: 443ms
# 844:	learn: 0.0224402	total: 2.4s	remaining: 440ms
# 845:	learn: 0.0224247	total: 2.4s	remaining: 437ms
# 846:	learn: 0.0224176	total: 2.4s	remaining: 434ms
# 847:	learn: 0.0224105	total: 2.41s	remaining: 431ms
# 848:	learn: 0.0223932	total: 2.41s	remaining: 428ms
# 849:	learn: 0.0223713	total: 2.41s	remaining: 426ms
# 850:	learn: 0.0223623	total: 2.41s	remaining: 423ms
# 851:	learn: 0.0223470	total: 2.42s	remaining: 420ms
# 852:	learn: 0.0223285	total: 2.42s	remaining: 417ms
# 853:	learn: 0.0223196	total: 2.42s	remaining: 414ms
# 854:	learn: 0.0223050	total: 2.42s	remaining: 411ms
# 855:	learn: 0.0222905	total: 2.43s	remaining: 408ms
# 856:	learn: 0.0222818	total: 2.43s	remaining: 405ms
# 857:	learn: 0.0222659	total: 2.43s	remaining: 402ms
# 858:	learn: 0.0222595	total: 2.43s	remaining: 400ms
# 859:	learn: 0.0222391	total: 2.44s	remaining: 397ms
# 860:	learn: 0.0222181	total: 2.44s	remaining: 394ms
# 861:	learn: 0.0222016	total: 2.44s	remaining: 391ms
# 862:	learn: 0.0221840	total: 2.44s	remaining: 388ms
# 863:	learn: 0.0221665	total: 2.45s	remaining: 385ms
# 864:	learn: 0.0221534	total: 2.45s	remaining: 382ms
# 865:	learn: 0.0221355	total: 2.45s	remaining: 380ms
# 866:	learn: 0.0221156	total: 2.46s	remaining: 377ms
# 867:	learn: 0.0220973	total: 2.46s	remaining: 374ms
# 868:	learn: 0.0220861	total: 2.46s	remaining: 371ms
# 869:	learn: 0.0220757	total: 2.46s	remaining: 368ms
# 870:	learn: 0.0220562	total: 2.47s	remaining: 365ms
# 871:	learn: 0.0220485	total: 2.47s	remaining: 362ms
# 872:	learn: 0.0220313	total: 2.47s	remaining: 360ms
# 873:	learn: 0.0220215	total: 2.47s	remaining: 357ms
# 874:	learn: 0.0219930	total: 2.48s	remaining: 354ms
# 875:	learn: 0.0219780	total: 2.48s	remaining: 351ms
# 876:	learn: 0.0219686	total: 2.48s	remaining: 348ms
# 877:	learn: 0.0219555	total: 2.48s	remaining: 345ms
# 878:	learn: 0.0219448	total: 2.49s	remaining: 342ms
# 879:	learn: 0.0219326	total: 2.49s	remaining: 339ms
# 880:	learn: 0.0219178	total: 2.49s	remaining: 337ms
# 881:	learn: 0.0219019	total: 2.49s	remaining: 334ms
# 882:	learn: 0.0218917	total: 2.5s	remaining: 331ms
# 883:	learn: 0.0218851	total: 2.5s	remaining: 328ms
# 884:	learn: 0.0218731	total: 2.5s	remaining: 325ms
# 885:	learn: 0.0218570	total: 2.5s	remaining: 322ms
# 886:	learn: 0.0218489	total: 2.51s	remaining: 319ms
# 887:	learn: 0.0218374	total: 2.51s	remaining: 317ms
# 888:	learn: 0.0218200	total: 2.51s	remaining: 314ms
# 889:	learn: 0.0218073	total: 2.52s	remaining: 311ms
# 890:	learn: 0.0217974	total: 2.52s	remaining: 308ms
# 891:	learn: 0.0217831	total: 2.52s	remaining: 305ms
# 892:	learn: 0.0217706	total: 2.52s	remaining: 302ms
# 893:	learn: 0.0217554	total: 2.52s	remaining: 299ms
# 894:	learn: 0.0217500	total: 2.53s	remaining: 297ms
# 895:	learn: 0.0217367	total: 2.53s	remaining: 294ms
# 896:	learn: 0.0217217	total: 2.53s	remaining: 291ms
# 897:	learn: 0.0217077	total: 2.54s	remaining: 288ms
# 898:	learn: 0.0216896	total: 2.54s	remaining: 285ms
# 899:	learn: 0.0216763	total: 2.54s	remaining: 282ms
# 900:	learn: 0.0216611	total: 2.54s	remaining: 280ms
# 901:	learn: 0.0216541	total: 2.55s	remaining: 277ms
# 902:	learn: 0.0216428	total: 2.55s	remaining: 274ms
# 903:	learn: 0.0216258	total: 2.55s	remaining: 271ms
# 904:	learn: 0.0216107	total: 2.55s	remaining: 268ms
# 905:	learn: 0.0215863	total: 2.56s	remaining: 265ms
# 906:	learn: 0.0215699	total: 2.56s	remaining: 262ms
# 907:	learn: 0.0215600	total: 2.56s	remaining: 260ms
# 908:	learn: 0.0215460	total: 2.56s	remaining: 257ms
# 909:	learn: 0.0215387	total: 2.57s	remaining: 254ms
# 910:	learn: 0.0215328	total: 2.57s	remaining: 251ms
# 911:	learn: 0.0215254	total: 2.57s	remaining: 248ms
# 912:	learn: 0.0215185	total: 2.58s	remaining: 245ms
# 913:	learn: 0.0215067	total: 2.58s	remaining: 243ms
# 914:	learn: 0.0214963	total: 2.58s	remaining: 240ms
# 915:	learn: 0.0214907	total: 2.58s	remaining: 237ms
# 916:	learn: 0.0214752	total: 2.58s	remaining: 234ms
# 917:	learn: 0.0214647	total: 2.59s	remaining: 231ms
# 918:	learn: 0.0214566	total: 2.59s	remaining: 228ms
# 919:	learn: 0.0214442	total: 2.59s	remaining: 226ms
# 920:	learn: 0.0214315	total: 2.6s	remaining: 223ms
# 921:	learn: 0.0214152	total: 2.6s	remaining: 220ms
# 922:	learn: 0.0214072	total: 2.6s	remaining: 217ms
# 923:	learn: 0.0213881	total: 2.6s	remaining: 214ms
# 924:	learn: 0.0213787	total: 2.61s	remaining: 211ms
# 925:	learn: 0.0213577	total: 2.61s	remaining: 209ms
# 926:	learn: 0.0213420	total: 2.61s	remaining: 206ms
# 927:	learn: 0.0213352	total: 2.61s	remaining: 203ms
# 928:	learn: 0.0213283	total: 2.62s	remaining: 200ms
# 929:	learn: 0.0213220	total: 2.62s	remaining: 197ms
# 930:	learn: 0.0213089	total: 2.62s	remaining: 194ms
# 931:	learn: 0.0212929	total: 2.63s	remaining: 192ms
# 932:	learn: 0.0212824	total: 2.63s	remaining: 189ms
# 933:	learn: 0.0212753	total: 2.63s	remaining: 186ms
# 934:	learn: 0.0212657	total: 2.63s	remaining: 183ms
# 935:	learn: 0.0212570	total: 2.64s	remaining: 180ms
# 936:	learn: 0.0212514	total: 2.64s	remaining: 178ms
# 937:	learn: 0.0212363	total: 2.64s	remaining: 175ms
# 938:	learn: 0.0212235	total: 2.65s	remaining: 172ms
# 939:	learn: 0.0212100	total: 2.65s	remaining: 169ms
# 940:	learn: 0.0212005	total: 2.65s	remaining: 166ms
# 941:	learn: 0.0211916	total: 2.65s	remaining: 163ms
# 942:	learn: 0.0211778	total: 2.66s	remaining: 161ms
# 943:	learn: 0.0211629	total: 2.66s	remaining: 158ms
# 944:	learn: 0.0211578	total: 2.66s	remaining: 155ms
# 945:	learn: 0.0211436	total: 2.67s	remaining: 152ms
# 946:	learn: 0.0211378	total: 2.67s	remaining: 149ms
# 947:	learn: 0.0211223	total: 2.67s	remaining: 147ms
# 948:	learn: 0.0211110	total: 2.67s	remaining: 144ms
# 949:	learn: 0.0210964	total: 2.68s	remaining: 141ms
# 950:	learn: 0.0210690	total: 2.68s	remaining: 138ms
# 951:	learn: 0.0210564	total: 2.68s	remaining: 135ms
# 952:	learn: 0.0210410	total: 2.68s	remaining: 132ms
# 953:	learn: 0.0210237	total: 2.69s	remaining: 130ms
# 954:	learn: 0.0210101	total: 2.69s	remaining: 127ms
# 955:	learn: 0.0210020	total: 2.69s	remaining: 124ms
# 956:	learn: 0.0209912	total: 2.69s	remaining: 121ms
# 957:	learn: 0.0209802	total: 2.7s	remaining: 118ms
# 958:	learn: 0.0209722	total: 2.7s	remaining: 115ms
# 959:	learn: 0.0209557	total: 2.7s	remaining: 113ms
# 960:	learn: 0.0209453	total: 2.71s	remaining: 110ms
# 961:	learn: 0.0209276	total: 2.71s	remaining: 107ms
# 962:	learn: 0.0209181	total: 2.71s	remaining: 104ms
# 963:	learn: 0.0208982	total: 2.71s	remaining: 101ms
# 964:	learn: 0.0208912	total: 2.72s	remaining: 98.5ms
# 965:	learn: 0.0208851	total: 2.72s	remaining: 95.7ms
# 966:	learn: 0.0208709	total: 2.72s	remaining: 92.9ms
# 967:	learn: 0.0208566	total: 2.73s	remaining: 90.1ms
# 968:	learn: 0.0208500	total: 2.73s	remaining: 87.3ms
# 969:	learn: 0.0208332	total: 2.73s	remaining: 84.5ms
# 970:	learn: 0.0208164	total: 2.73s	remaining: 81.6ms
# 971:	learn: 0.0208090	total: 2.74s	remaining: 78.8ms
# 972:	learn: 0.0207886	total: 2.74s	remaining: 76ms
# 973:	learn: 0.0207693	total: 2.74s	remaining: 73.2ms
# 974:	learn: 0.0207517	total: 2.74s	remaining: 70.4ms
# 975:	learn: 0.0207465	total: 2.75s	remaining: 67.5ms
# 976:	learn: 0.0207372	total: 2.75s	remaining: 64.7ms
# 977:	learn: 0.0207182	total: 2.75s	remaining: 61.9ms
# 978:	learn: 0.0207069	total: 2.75s	remaining: 59.1ms
# 979:	learn: 0.0206972	total: 2.76s	remaining: 56.3ms
# 980:	learn: 0.0206888	total: 2.76s	remaining: 53.5ms
# 981:	learn: 0.0206817	total: 2.76s	remaining: 50.7ms
# 982:	learn: 0.0206698	total: 2.77s	remaining: 47.8ms
# 983:	learn: 0.0206539	total: 2.77s	remaining: 45ms
# 984:	learn: 0.0206489	total: 2.77s	remaining: 42.2ms
# 985:	learn: 0.0206381	total: 2.77s	remaining: 39.4ms
# 986:	learn: 0.0206248	total: 2.78s	remaining: 36.6ms
# 987:	learn: 0.0206117	total: 2.78s	remaining: 33.8ms
# 988:	learn: 0.0206050	total: 2.78s	remaining: 30.9ms
# 989:	learn: 0.0205892	total: 2.78s	remaining: 28.1ms
# 990:	learn: 0.0205823	total: 2.79s	remaining: 25.3ms
# 991:	learn: 0.0205677	total: 2.79s	remaining: 22.5ms
# 992:	learn: 0.0205576	total: 2.79s	remaining: 19.7ms
# 993:	learn: 0.0205497	total: 2.79s	remaining: 16.9ms
# 994:	learn: 0.0205337	total: 2.8s	remaining: 14.1ms
# 995:	learn: 0.0205122	total: 2.8s	remaining: 11.2ms
# 996:	learn: 0.0205006	total: 2.8s	remaining: 8.43ms
# 997:	learn: 0.0204918	total: 2.81s	remaining: 5.62ms
# 998:	learn: 0.0204841	total: 2.81s	remaining: 2.81ms
# 999:	learn: 0.0204806	total: 2.81s	remaining: 0us

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4593
#            1       0.17      0.05      0.08        19
#            2       0.72      0.89      0.79       158
#            3       0.20      0.07      0.10        44
#
#     accuracy                           0.98      4814
#    macro avg       0.52      0.50      0.49      4814
# weighted avg       0.98      0.98      0.98      4814

# %%
# function/module/compoenets def area

def Header2(name, app):
    title = html.H2(name, style={"margin-top": 5})
    return dbc.Row([dbc.Col(title, md=9)])
#style={'text-align': 'center', 'font-size': '20px'}
def Header1(name, app):
    title = html.H1(name, style={"margin-top": 5})
    return dbc.Row([dbc.Col(title, md=9)])

# Card components

# Basement Cards
cards = [
    dbc.Card(
        [
            html.H2(f"+{5/45*100:.2f}%", className="card-title"),
            html.P("HMR 시장규모 증가(2021~2022)", className="card-text"),
        ],
        body=True,
        color="#334557",
        inverse=True,
    ),
    dbc.Card(
        [
            html.H2(f"-38%", className="card-title"),
            html.P("수주금액 변동추이(2018~2021)", className="card-text"),
        ],
        body=True,
        color="#588195",
        inverse=True,
    ),
]

# Analyze Cards
cards2 = [
    dbc.Card(
        [
            html.H2(f"상관관계↑", className="card-title"),
            html.P("즉석밥 생산수와 오류발생", className="card-text"),
        ],
        body=True,
        color="#334557",
        inverse=True,
    ),
    dbc.Card(
        [
            html.H2(f"5% 이하", className="card-title"),
            html.P("최근 오류발생률", className="card-text"),
        ],
        body=True,
        color="#588195",
        inverse=True,
    ),
]

cards4 = [
    dbc.Card(
        [
            html.H2(f"75분 / 44분 ", className="card-title"),
            html.P("평균 생산시간/오류발생시간", className="card-text"),
        ],
        body=True,
        color="#334557",
        inverse=True,
    ),
    dbc.Card(
        [
            html.H2(f"0:정상 / 1:공정전 / 2:공정중 / 3:기타", className="card-title"),
            html.P("오류메세지 분류", className="card-text"),
        ],
        body=True,
        color="#588195",
        inverse=True,
    ),
]

cards5 = [
    dbc.Card(
        [
            html.H2(f"충전실온도 / 실링온도 / 쿠킹온도 / 쿠킹스팀압력 / 실링압력", className="card-title"),
            html.P("오류발생 현황과 주 요인", className="card-text"),
        ],
        body=True,
        color="#334557",
        inverse=True,
    ),
]

# Predict Cards(추후 추가)
cards3 = [
    dbc.Card(
        [
            html.H2(f"{train_score:.4f} / {test_score:.4f}", className="card-title"),
            html.P("Train / Test Score", className="card-text"),
        ],
        body=True,
        color="#334557",
        inverse=True,
    ),
    dbc.Card(
        [
            html.H2(f"{f1_score_df.iloc[4,2]}", className="card-title"),
            html.P("Weighted Avg f1-score", className="card-text"),
        ],
        body=True,
        color="#588195",
        inverse=True,
    ),
    dbc.Card(
        [
            html.H2(f"CatBoost Classifier", className="card-title"),
            html.P("Machine Learning Model", className="card-text"),
        ],
        body=True,
        color="#EFF0F2",
        inverse=False,
    ),
]

# Graph components
# Basement_Graphs
graphs1 = [[dcc.Graph(id="update_graph"), #1행 1열
            dcc.RangeSlider(hmrexpand['year'].min(),
                            hmrexpand['year'].max(),
                            value=[hmrexpand['year'].min(), hmrexpand['year'].max()], #수정사항, 슬라이더 초기값(처음값과 끝값)
                            marks={str(year): str(year) for year in hmrexpand['year'].unique()}, #수정사항 RangeSlider, Slider 모두에 적용
                            id='slider1')]
            , [dcc.Graph(id="update_graph2", figure=fig3)]] #1행 2열

graphs2 = [[dcc.Graph(id='booking-with-graph'), #2행 1열
            dcc.RangeSlider(id='year-slider',
                            min=year_earn['year'].min(),
                            max=year_earn['year'].max(),
                            value=[year_earn['year'].min(), year_earn['year'].max()],
                            marks={str(year): str(year) for year in year_earn['year'].unique()})],
           [dcc.Graph(id='yearly-transaction-graph'), #2행 2열
            dcc.RangeSlider(id='year-slider2',
                            min= buyer['year'].min(),
                            max= buyer['year'].max(),
                            step=None,
                            value=[buyer['year'].min(), buyer['year'].max()],
                            marks={str(year): str(year) for year in buyer['year'].unique()})
            ]]
        
# Analyze Graph

#1행

graphs3 = [[dcc.Graph(id="lines"),
            dcc.Dropdown(id='lines-select',
                         options=[{'label':'분기별 생산품목과 오류발생', 'value':'fig_line1'},
                                  {'label':'생산수에 따른 오류발생 여부', 'value':'fig_line2'}],
                         value='fig_line1'
                         )],
            [dcc.Graph(id='Error_per'), 
            dcc.RangeSlider(id='year-per',
                            min=Error_per['year'].min(),
                            max=Error_per['year'].max(),
                            value=[Error_per['year'].min(), Error_per['year'].max()],
                            marks={str(year): str(year) for year in Error_per['year'].unique()})
            ]]  

#2행
graphs4 = [[dcc.Graph(id="vios2"),
            dcc.Dropdown(id='violin-select',
                         options = [{'label':'평균 생산시간', 'value':'평균 생산시간'},
                                    {'label':'평균 오류발생시간', 'value':'평균 오류발생시간'}],
                         value='평균 생산시간'
                         )],
            [dcc.Graph(id="pies"), 
            dcc.Dropdown(id='pie-select',
                         options=[{'label':'오류메세지 분류(총 110종)', 'value':'fig_pie1'},
                                  {'label':'전체오류(1074건) 재분류 후 분포', 'value':'fig_pie2'}],
                         value='fig_pie1'
                         )]
            ]

#3행
graphs5 = [[dcc.Graph(id="scatter-5"),
            dcc.Dropdown(id='yvar_name',
                     options=scatter5_names,
                     value=scatter5_names[0],
                     placeholder='Select X-axis column')]  
           ]


# Predict Graph
radio_items1 = dcc.RadioItems(
    id='barr',
    options=[
        {'label': 'Train/Test Score', 'value': 'bar_1'},
        {'label': 'Catboost Multiclass', 'value': 'bar_2'}
    ],
    value='bar_2'
)

graphs6 = [
    dcc.Graph(id="bars")
]

#hr_style def
hr_style = {
    'border': '3px solid black' , # 선 두께와 색상을 지정합니다.
}

# 메뉴바 정의
menu = dbc.NavbarSimple(
    children=[
        dbc.NavItem(dbc.NavLink("Current Situation", href="/basement")),
        dbc.NavItem(dbc.NavLink("Analysis", href="/analyze")),
        dbc.NavItem(dbc.NavLink("Modeling/Predict", href="/predict")),
    ],
    brand="불량예측 모델을 통한 수익성 개선, 알파코 AI엔지니어 부트캠프 5기, 5조",
    brand_href="/",
    sticky="top",
    color="black",
    dark=True,
)

#이미지 정의부

image_filename1 = 'data/conclusion.png'
encoded_image1 = base64.b64encode(open(image_filename1, 'rb').read())

# %%
#페이지별 레이아웃 정의 Area

app = JupyterDash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

# 각 페이지별 레이아웃
basement_layout = dbc.Container(
    [
        html.Br(),
        Header1("Current Situation", app),
        html.Br(),
        dbc.Row([dbc.Col(card) for card in cards]),
        html.Hr(),
        dbc.Row([dbc.Col(graph) for graph in graphs1]),
        html.Br(),
        dbc.Row([dbc.Col(graph) for graph in graphs2]),
        html.Br(),
    ], 
    fluid=False,
)

analyze_layout = dbc.Container(
    [
        html.Br(),
        Header1("Analysis", app),
        html.Br(),
        dbc.Row([dbc.Col(card) for card in cards2]),
        html.Hr(),        
        dbc.Row([dbc.Col(graph) for graph in graphs3]), #그래프4 (파이)
        html.Br(),
        dbc.Row([dbc.Col(card) for card in cards4]),
        html.Hr(),
        dbc.Row([dbc.Col(graph) for graph in graphs4]), #그래프4 (파이)
        html.Br(),
        dbc.Row([dbc.Col(card) for card in cards5]),
        html.Hr(),
        dbc.Row([dbc.Col(graph) for graph in graphs5]), #그래프5 (스캐터)
        html.Br(),
    ], 
    fluid=False,
)

predict_layout = dbc.Container(
    [
        html.Br(),
        Header1("Modeling", app),
        html.Br(),
        dbc.Row([dbc.Col(card) for card in cards3]),
        html.Hr(),
        dbc.Row(
            [
                dbc.Col(
                    [
                        radio_items1,
                        dcc.Graph(id="bars"),
                    ],
                    md=6, # 1행 2열에서 오른쪽 열
                    align='center', 
                ),
                dbc.Col(
                    [
                        html.Img(id='image-display', className='img-fluid', width=600, src='data:image/png;base64,{}'.format(encoded_image1.decode())),                                                
                    ], 
                    md=6, # 1행 2열에서 왼쪽 열
                    align='center', 
                ),
                
            ],
             justify='center' 
        ),
        html.Br(),
        html.Br(),
        html.Hr(), #hr_style 적용 예시 
        Header1("Predict", app),
        html.Br(), 
        html.Div(
            [
                dbc.Row(
                    [
                        dbc.Col(
                            [
                                html.Label('충전실 온도'),
                                dcc.Slider(id='input1', min=68, max=75, value=71, step=0.1, marks={68: '68', 69: '69', 70: '70', 71: '71', 72: '72', 73: '73', 74: '74', 75: '75'})
                            ],
                            md=6,
                            style={'padding': '10px'}
                        ),
                        dbc.Col(
                            [
                                html.Label('실링 온도'),
                                dcc.Slider(id='input2', min=65, max=141, value=101, step=0.1, marks={65: '65', 75: '75', 85: '85', 95: '95', 105: '105', 115: '115', 125: '125', 135: '135', 141: '141'})
                            ],
                            md=6,
                            style={'padding': '10px'}
                        )
                    ]
                ),
                dbc.Row(
                    [
                        dbc.Col(
                            [
                                html.Label('쿠킹 온도'),
                                dcc.Slider(id='input3', min=100, max=177, value=137, step=0.1, marks={100: '100', 110: '110', 120: '120', 130: '130', 140: '140', 150: '150', 160: '160', 170: '170', 177: '177'})
                            ],
                            md=6,
                            style={'padding': '10px'}
                        ),
                        dbc.Col(
                            [
                                html.Label('쿠킹 스팀압력'),
                                dcc.Slider(id='input4', min=22, max=25, value=23.5, step=0.01, marks={22: '22', 22.5: '22.5', 23: '23', 23.5: '23.5', 24: '24', 24.5: '24.5', 25: '25'})
                            ],
                            md=6,
                            style={'padding': '10px'}
                        )
                    ]
                ),
                dbc.Row(
                    [
                        dbc.Col(
                            [
                                html.Label('실링 압력'),
                                dcc.Slider(id='input5', min=192, max=223, value=208, step=0.1, marks={192: '192', 195: '195', 200: '200', 205: '205', 210: '210', 215: '215', 220: '220', 223: '223'})
                            ],
                            md=6,
                            style={'padding': '10px'}
                        ),
                        dbc.Col(
                            [
                                html.Button(id='submit-button', n_clicks=0, children='결과확인', style={'text-align': 'center', 'font-size': '20px'}),                                
                            ],
                            md=6,
                            style={'padding': '20px', 'display': 'flex', 'justify-content': 'center'}
                        )
                    ]
                )
            ],            
        ),
        html.Br(),        
        html.Div(id='output', style={'text-align': 'center', 'font-size': '20px'}),
        html.Br()  
    ],
    fluid=False,
)

# %%
# 전체 레이아웃 Area
app.layout = html.Div(
    [
        menu,
        dcc.Location(id="url"),
        html.Div(id="page-content"),
    ]
)

# %%
#@Callback Area

# 각 페이지별 앱 콜백
@app.callback(
    Output("page-content", "children"),
    Input("url", "pathname"),
)
def render_page_content(pathname):
    if pathname == "/basement":
        return basement_layout
    elif pathname == "/analyze":
        return analyze_layout
    elif pathname == "/predict":
        return predict_layout
    else:
        return basement_layout

# %%
#@Callback Area
#Basement Graph Callback list
    #그래프 1행 1열 콜백
@app.callback(
    Output(component_id='update_graph', component_property='figure'), 
    Input(component_id='slider1', component_property='value')
)
def update_graph(year):
    filtered_df = hmrexpand[(hmrexpand['year'] >= year[0]) & (hmrexpand['year'] <= year[1])] #수정사항, 슬라이더 값지정하는 임시 df생성
    fig1 = px.bar(filtered_df, x=filtered_df['year'], y=filtered_df['market'])
    fig1.update_layout(
    title={
        'text': "HMR Market Changes",
        'font': {'size': 20},
        'x': 0.5
    },
    xaxis_title="연도",
    yaxis_title="시장규모",
    font=dict(size=15)
)       
    return(fig1)


    #그래프 2행 1열 콜백
@app.callback(
    Output(component_id='booking-with-graph', component_property='figure'), 
    Input(component_id='year-slider', component_property='value')
)
def update_graph2(year):
    filtered_df2 = year_earn[(year_earn['year'] >= year[0]) & (year_earn['year'] <= year[1])]
    fig2 = px.bar(filtered_df2, x='year', y='수주금액')
    fig2.update_layout(
    title={
        'text': "연도별 수주금액추이",
        'font': {'size': 20},
        'x': 0.5
    },
    xaxis_title="연도",
    font=dict(size=15)
)
    return(fig2)           

    #그래프 2행 2열 콜백
@app.callback(
    Output(component_id='yearly-transaction-graph', component_property='figure'),
    Input(component_id='year-slider2', component_property='value')
)
def update_figure(selected_years):
    filtered_df3 = buyer[(buyer['year'] >= selected_years[0]) & (buyer['year'] <= selected_years[1])]
    fig4 = px.bar(filtered_df3, x=filtered_df3['year'], y=filtered_df3['거래처코드'])
    fig4.update_layout(
    title={
        'text': "연도별 거래건수 변동추이",
        'font': {'size': 20},
        'x': 0.5
    },
    xaxis_title="연도",
    yaxis_title="거래건수",
    font=dict(size=15)
)
    return fig4

# %%
#Analyze Graph Callback list
    #그래프 1행 1열 콜백
@app.callback(
    Output(component_id='lines', component_property='figure'),
    Input(component_id='lines-select', component_property='value')
)
def update_graph1by1(selected_value):
    if selected_value == 'fig_line1':
        fig = make_subplots(specs=[[{"secondary_y": True}]])
        fig.add_trace(
        go.Scatter( x = cooking_error_quarter["quarter"], y = cooking_error_quarter["생산수"],
        mode = 'lines', name = '분기별 간편식 생산품목 수'),
        secondary_y=False,)
        fig.add_trace(
        go.Scatter( x = cooking_error_quarter["quarter"], y = cooking_error_quarter["오류발생여부"],
        mode = 'lines', name = '분기별 오류발생 현황'),
        secondary_y=True,)        
# # Add figure title
        fig.update_layout(title={'text': "분기별 생산품목과 오류발생", 'font': {'size': 20}, 'x': 0.5}, xaxis_title="분기", font=dict(size=15), legend=dict(x=0.17, y=1.15, font=dict(size=10), orientation="h"), xaxis_tickfont=dict(size=10))    
        fig.update_yaxes(title_text="생산품목", secondary_y=False, title_font=dict(size=20), title_standoff=10)
        fig.update_yaxes(title_text="오류발생", secondary_y=True, title_font=dict(size=20), title_standoff=10)
        return(fig)
    else:
        fig2 = px.scatter(cooking_error_quarter, x=cooking_error_quarter["생산수"], y=cooking_error_quarter["오류발생여부"], trendline="ols")
        fig2.update_layout(title={'text': "생산수에 따른 오류발생 여부", 'font': {'size': 20}, 'x': 0.5},
                           xaxis_title="생산품목 수",
                           yaxis_title="오류발생",
                           font=dict(size=15))
        return(fig2)    

    #그래프 1행 2열 콜백
@app.callback(
    Output(component_id='Error_per', component_property='figure'), 
    Input(component_id='year-per', component_property='value')
)
def update_graph1by2(year):
    filtered_year_per = Error_per[(Error_per['year'] >= year[0]) & (Error_per['year'] <= year[1])]
    fig_year_per = px.line(filtered_year_per, x='year', y='per', text='per')
    fig_year_per.update_traces(textposition="bottom right")
    fig_year_per.update_layout(
        title={'text': "연도별 오류발생률",
               'font': {'size': 20},
               'x': 0.5},
        xaxis_title="연도",
        yaxis_title="오류발생률",
        font=dict(size=15))
    return(fig_year_per)           

    #그래프 2행 1열 콜백
@app.callback(
    Output(component_id='vios2', component_property='figure'),
    Input(component_id='violin-select', component_property='value')
)
def update_graph2by1(selected_value):
    if selected_value == '평균 생산시간':
        vio1 = px.violin(violin_cooking, box=True, y='생산시간')
        vio1.update_layout(
        title={'text': "평균 생산시간",
               'font': {'size': 20},
               'x': 0.5},
        yaxis_title="생산시간",
        font=dict(size=15))
        return vio1
    else:
        vio2 = px.violin(violin_error, box=True, y='오류조치시간_보정')
        vio2.update_layout(
        title={'text': "오류조치 소요시간",
               'font': {'size': 20},
               'x': 0.5},
        yaxis_title="오류조치시간",
        font=dict(size=15))
        return vio2

    #그래프 2행 2열 콜백
@app.callback(
    Output(component_id='pies', component_property='figure'),
    Input(component_id='pie-select', component_property='value')
)
def update_graph2by2(selected_value):
    if selected_value == 'fig_pie1':
        fig_pie1 = px.pie(pie1, values='Error_class', names=pie1.index)
        fig_pie1.update_layout(title={'text': "오류메세지(110종) 분류",
                                      'font': {'size': 20},
                                      'x': 0.5},                                
                                font=dict(size=15))
        return fig_pie1
    else:
        fig_pie2 = px.pie(pie2, values='Error_class', names=pie2.index)
        fig_pie2.update_layout(title={'text': "전체오류(1074건) 재분류 후 분포",
                                'font': {'size': 20},
                                'x': 0.5},
                                font=dict(size=15))
        return fig_pie2
    
    #그래프 3행 1열 콜백
@app.callback(
    Output(component_id='scatter-5', component_property='figure'),
     Input(component_id='yvar_name', component_property='value')
)
def update_graph3by1(yvar):
    fig = px.scatter(scatter5, x=scatter5['생산일자'], y=yvar, color=scatter5['오류발생여부'])
    fig.update_layout(title={'text': "오류발생요인("+yvar+')에 따른 오류제품 분포',
                             'font': {'size': 20},
                             'x': 0.5}, font=dict(size=15))
    return(fig)

# %%
#Predict Graph Callback list
    #그래프 1행 1열 콜백      
@app.callback(
    Output(component_id="bars", component_property='figure'),
    Input(component_id='barr', component_property='value')
)
def update_graph(selected_value):
    if selected_value == 'bar_1':
       fig = go.Figure(data=[go.Bar(x=['Train', 'Test'], y=[train_score, test_score])])
       fig.update_layout(title='Train/Test Score', yaxis_title='Accuracy')
       return fig

    else:    
       fig2 = go.Figure([go.Bar(x=X.columns, y=importance)])
       fig2.update_layout(title='Catboost Multiclass', yaxis_title='온도와 압력')
       return fig2
    #그래프 1행 2열 콜백

    #그래프 2행 1열 콜백

    #그래프 2행 2열 콜백

    #그래프 3행 1열 콜백(예측 예제 콜백 전용 구간)
@app.callback(
    dash.dependencies.Output('output', 'children'),
    [dash.dependencies.Input('submit-button', 'n_clicks')],
    [dash.dependencies.State('input1', 'value'),
     dash.dependencies.State('input2', 'value'),
     dash.dependencies.State('input3', 'value'),
     dash.dependencies.State('input4', 'value'),
     dash.dependencies.State('input5', 'value')])
def predict(n_clicks, input1, input2, input3, input4, input5):
    # 입력 데이터 정규화
    input_data = np.array([[input1, input2, input3, input4, input5]])
        
    # 모델 예측
    prediction = model.predict(input_data)
    
    # 예측 결과 반환    
    if prediction == 0:
        return html.Div([
            f'충전실 온도: {input1}, 실링 온도: {input2}, 쿠킹 온도: {input3}, 쿠킹 스팀압력: {input4}, 실링 압력: {input5}',
            html.Br(),
            f'예측 결과: 정상 생산'
        ], style={'font-size': '20px', 'text-align': 'center'})
    else:
        return html.Div([
            f'충전실 온도: {input1}, 실링 온도: {input2}, 쿠킹 온도: {input3}, 쿠킹 스팀압력: {input4}, 실링 압력: {input5}',
            html.Br(),
            f'예측 결과: 오류 발생 - 에러코드 {prediction}'
        ], style={'font-size': '20px', 'text-align': 'center'})

# %%
# APP excute
if __name__ == '__main__':
    app.run_server(debug=True, mode='inline', host='127.0.0.1')
# Out:
# Dash is running on http://127.0.0.1:8050/
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
