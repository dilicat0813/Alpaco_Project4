# %%
# Install modules

# %pip install dash
# %pip install jupyter-dash
# %pip install dash-bootstrap-components
# %pip install statsmodels

# Import Modules
import dash
import pandas as pd
import plotly.express as px
from jupyter_dash import JupyterDash
from dash import Dash, dcc, html, Input, Output, State
import dash_bootstrap_components as dbc
import plotly.graph_objs as go
import plotly.graph_objects as go
from plotly.subplots import make_subplots
# from dash.dependencies import Input, Output, State

# %%
#dbc.img 와 dbc.butten 만들기
# import dash_bootstrap_components as dbc
# import dash_html_components as html
# from dash.dependencies import Input, Output, State

app = JupyterDash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

app.layout = dbc.Container(
    [
    html.Img(src='https://img.hankyung.com/photo/202111/PEP20200720164101055_P4.jpg'),
    dbc.Button('바셀 메시', id='btn-1', n_clicks=0, className='mr-2'),
    dbc.Button('아르헨 메시', id='btn-2', n_clicks=0, className='mr-2'),
    dbc.Button('파리 메시', id='btn-3', n_clicks=0, className='mr-2'),
    ],
    fluid=False
)

#버튼 클릭시 이미지가 바뀌는 콜백함수 지정
@app.callback(
    Output('image', 'src'),
    [Input('btn-1', 'n_clicks1'),
     Input('btn-2', 'n_clicks2'),
     Input('btn-3', 'n_clicks3')]
)
def update_image(n_clicks1, n_clicks2, n_clicks3, current_src):
    if n_clicks1 > 0:
        return 'https://blog.kakaocdn.net/dn/cjm1ao/btrbor1V4M4/M79GDry75P87v6EiC22pD1/img.png'
    elif n_clicks2 > 0:
        return 'https://newsimg-hams.hankookilbo.com/2022/10/18/5e8cbea0-b91e-4774-b5e0-3060e1b0e4cb.jpg'
    elif n_clicks3 > 0:
        return 'https://image.newsis.com/2023/02/19/NISI20230219_0019789249_web.jpg'
    else:
        return current_src

if __name__ == '__main__':
    app.run_server(debug=True, mode='inline', host='127.0.0.1')

# %%
app = JupyterDash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

app.layout = dbc.Container(
    [
        html.Img(id='image', src='https://img.hankyung.com/photo/202111/PEP20200720164101055_P4.jpg'),
        dbc.Button('바셀 메시', id='btn-1', n_clicks=0, className='mr-2'),
        dbc.Button('아르헨 메시', id='btn-2', n_clicks=0, className='mr-2'),
        dbc.Button('파리 메시', id='btn-3', n_clicks=0, className='mr-2'),
    ],
    fluid=False,
)

# 버튼 클릭시 이미지가 바뀌는 콜백함수 지정
@app.callback(
    Output('image', 'src'),
    [Input('btn-1', 'n_clicks'),
     Input('btn-2', 'n_clicks'),
     Input('btn-3', 'n_clicks')],
    [State('image', 'src')]
)
def update_image(n_clicks1, n_clicks2, n_clicks3, current_src=None):
    if n_clicks1 == 1:
        n_clicks1 == 0
        return 'https://blog.kakaocdn.net/dn/cjm1ao/btrbor1V4M4/M79GDry75P87v6EiC22pD1/img.png'
    elif n_clicks2 == 1:
        n_clicks2 == 0
        return 'https://newsimg-hams.hankookilbo.com/2022/10/18/5e8cbea0-b91e-4774-b5e0-3060e1b0e4cb.jpg'
    elif n_clicks3 == 1:
        n_clicks3 == 0
        return 'https://image.newsis.com/2023/02/19/NISI20230219_0019789249_web.jpg'
    else:
        return current_src

if __name__ == '__main__':
    app.run_server(debug=True, mode='inline', host='127.0.0.2')
